# %% [markdown]
# <a href="https://colab.research.google.com/github/traceswrldd/traceswrldd/blob/main/week_9_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #data analysis and preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Foreign_Exchange_Rates.xlsx")

# %%
df.head(), df.columns
# Out:
# (  ,Time Serie,AUSTRALIA - AUSTRALIAN DOLLAR/US$,EURO AREA - EURO/US$,NEW ZEALAND - NEW ZELAND DOLLAR/US$,UNITED KINGDOM - UNITED KINGDOM POUND/US$,BRAZIL - REAL/US$,CANADA - CANADIAN DOLLAR/US$,CHINA - YUAN/US$,HONG KONG - HONG KONG DOLLAR/US$,INDIA - INDIAN RUPEE/US$,KOREA - WON/US$,MEXICO - MEXICAN PESO/US$,SOUTH AFRICA - RAND/US$,SINGAPORE - SINGAPORE DOLLAR/US$,DENMARK - DANISH KRONE/US$,JAPAN - YEN/US$,MALAYSIA - RINGGIT/US$,NORWAY - NORWEGIAN KRONE/US$,SWEDEN - KRONA/US$,SRI LANKA - SRI LANKAN RUPEE/US$,SWITZERLAND - FRANC/US$,TAIWAN - NEW TAIWAN DOLLAR/US$,THAILAND - BAHT/US$,
#  0  0,03-01-2000,1.5172,0.9847,1.9033,0.6146,1.805...
#  1  1,04-01-2000,1.5239,0.97,1.9238,0.6109,1.8405,...
#  2  2,05-01-2000,1.5267,0.9676,1.9339,0.6092,1.856...
#  3  3,06-01-2000,1.5291,0.9686,1.9436,0.607,1.84,1...
#  4  4,07-01-2000,1.5272,0.9714,1.938,0.6104,1.831,...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ,
#  Index([',Time Serie,AUSTRALIA - AUSTRALIAN DOLLAR/US$,EURO AREA - EURO/US$,NEW ZEALAND - NEW ZELAND DOLLAR/US$,UNITED KINGDOM - UNITED KINGDOM POUND/US$,BRAZIL - REAL/US$,CANADA - CANADIAN DOLLAR/US$,CHINA - YUAN/US$,HONG KONG - HONG KONG DOLLAR/US$,INDIA - INDIAN RUPEE/US$,KOREA - WON/US$,MEXICO - MEXICAN PESO/US$,SOUTH AFRICA - RAND/US$,SINGAPORE - SINGAPORE DOLLAR/US$,DENMARK - DANISH KRONE/US$,JAPAN - YEN/US$,MALAYSIA - RINGGIT/US$,NORWAY - NORWEGIAN KRONE/US$,SWEDEN - KRONA/US$,SRI LANKA - SRI LANKAN RUPEE/US$,SWITZERLAND - FRANC/US$,TAIWAN - NEW TAIWAN DOLLAR/US$,THAILAND - BAHT/US$,'], dtype='object'))

# %%
#skip rows - this step is no longer needed in this approach
#df = pd.read_excel("Foreign_Exchange_Rates.xlsx", skiprows=1)

# %%
#rename the first column - this step is no longer needed as we will rename the date column later
#df.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)

# %%
#convert the 'Time Serie' column to a datetime format
df['Time Serie'] = pd.to_datetime(df['Time Serie'], dayfirst=True, errors='coerce')

# %%
# Read the first row to get column names
header_df = pd.read_excel("Foreign_Exchange_Rates.xlsx", skiprows=0, nrows=1)
display(header_df)
# Out:
#   ,Time Serie,AUSTRALIA - AUSTRALIAN DOLLAR/US$,EURO AREA - EURO/US$,NEW ZEALAND - NEW ZELAND DOLLAR/US$,UNITED KINGDOM - UNITED KINGDOM POUND/US$,BRAZIL - REAL/US$,CANADA - CANADIAN DOLLAR/US$,CHINA - YUAN/US$,HONG KONG - HONG KONG DOLLAR/US$,INDIA - INDIAN RUPEE/US$,KOREA - WON/US$,MEXICO - MEXICAN PESO/US$,SOUTH AFRICA - RAND/US$,SINGAPORE - SINGAPORE DOLLAR/US$,DENMARK - DANISH KRONE/US$,JAPAN - YEN/US$,MALAYSIA - RINGGIT/US$,NORWAY - NORWEGIAN KRONE/US$,SWEDEN - KRONA/US$,SRI LANKA - SRI LANKAN RUPEE/US$,SWITZERLAND - FRANC/US$,TAIWAN - NEW TAIWAN DOLLAR/US$,THAILAND - BAHT/US$,
# 0  0,03-01-2000,1.5172,0.9847,1.9033,0.6146,1.805...

# %%
# Load the data into a single column, skipping initial metadata if any
# Based on previous output, it seems the actual data starts from row 1 (index 0)
df = pd.read_excel("Foreign_Exchange_Rates.xlsx", header=None)

# The data is in the first column (index 0) and is comma-separated
# Split the single column into multiple columns based on the comma delimiter
df = df[0].str.split(',', expand=True)

# The first row of the split dataframe contains the column names
column_names = df.iloc[0].tolist()

# Assign the column names
df.columns = column_names

# Remove the header row from the data
df = df[1:].reset_index(drop=True)

# Display the first few rows and the columns to verify
display(df.head())
display(df.columns)
# Out:
#       Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0  0  03-01-2000                            1.5172               0.9847
# 1  1  04-01-2000                            1.5239                 0.97
# 2  2  05-01-2000                            1.5267               0.9676
# 3  3  06-01-2000                            1.5291               0.9686
# 4  4  07-01-2000                            1.5272               0.9714
#
#   NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                              1.9033
# 1                              1.9238
# 2                              1.9339
# 3                              1.9436
# 4                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# 2                                    0.6092             1.856
# 3                                     0.607              1.84
# 4                                    0.6104             1.831
#
#   CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                       1.4465           8.2798
# 1                       1.4518           8.2799
# 2                       1.4518           8.2798
# 3                       1.4571           8.2797
# 4                       1.4505           8.2794
#
#   HONG KONG - HONG KONG DOLLAR/US$  ... DENMARK - DANISH KRONE/US$  \
# 0                           7.7765  ...                      7.329
# 1                           7.7775  ...                      7.218
# 2                            7.778  ...                      7.208
# 3                           7.7785  ...                     7.2125
# 4                           7.7783  ...                     7.2285
#
#   JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$  \
# 0           101.7                    3.8                        7.964
# 1          103.09                    3.8                        7.934
# 2          103.77                    3.8                        7.935
# 3          105.19                    3.8                         7.94
# 4          105.17                    3.8                        7.966
#
#   SWEDEN - KRONA/US$ SRI LANKA - SRI LANKAN RUPEE/US$ SWITZERLAND - FRANC/US$  \
# 0              8.443                             72.3                  1.5808
# 1               8.36                            72.65                  1.5565
# 2              8.353                            72.95                  1.5526
# 3             8.3675                            72.95                   1.554
# 4              8.415                            73.15                  1.5623
#
#   TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$
# 0                          31.38               36.97
# 1                           30.6               37.13
# 2                           30.8                37.1
# 3                          31.75               37.62
# 4                          30.85                37.3
#
# [5 rows x 25 columns]
# Index(['', 'Time Serie', 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
#        'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
#        'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$',
#        'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$',
#        'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$',
#        'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$',
#        'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$',
#        'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$',
#        'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$',
#        'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$',
#        'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$',
#        'THAILAND - BAHT/US$', ''],
#       dtype='object')

# %%
# Replace 'ND' values with NaN
df.replace('ND', np.nan, inplace=True)

# Display the head to see the changes (optional)
display(df.head())
# Out:
#      Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0  0 2000-01-03                            1.5172               0.9847
# 1  1 2000-01-04                            1.5239                 0.97
# 2  2 2000-01-05                            1.5267               0.9676
# 3  3 2000-01-06                            1.5291               0.9686
# 4  4 2000-01-07                            1.5272               0.9714
#
#   NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                              1.9033
# 1                              1.9238
# 2                              1.9339
# 3                              1.9436
# 4                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# 2                                    0.6092             1.856
# 3                                     0.607              1.84
# 4                                    0.6104             1.831
#
#   CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                       1.4465           8.2798
# 1                       1.4518           8.2799
# 2                       1.4518           8.2798
# 3                       1.4571           8.2797
# 4                       1.4505           8.2794
#
#   HONG KONG - HONG KONG DOLLAR/US$  ... DENMARK - DANISH KRONE/US$  \
# 0                           7.7765  ...                      7.329
# 1                           7.7775  ...                      7.218
# 2                            7.778  ...                      7.208
# 3                           7.7785  ...                     7.2125
# 4                           7.7783  ...                     7.2285
#
#   JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$  \
# 0           101.7                    3.8                        7.964
# 1          103.09                    3.8                        7.934
# 2          103.77                    3.8                        7.935
# 3          105.19                    3.8                         7.94
# 4          105.17                    3.8                        7.966
#
#   SWEDEN - KRONA/US$ SRI LANKA - SRI LANKAN RUPEE/US$ SWITZERLAND - FRANC/US$  \
# 0              8.443                             72.3                  1.5808
# 1               8.36                            72.65                  1.5565
# 2              8.353                            72.95                  1.5526
# 3             8.3675                            72.95                   1.554
# 4              8.415                            73.15                  1.5623
#
#   TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$
# 0                          31.38               36.97
# 1                           30.6               37.13
# 2                           30.8                37.1
# 3                          31.75               37.62
# 4                          30.85                37.3
#
# [5 rows x 25 columns]

# %%
# Identify exchange rate columns (all except the first two and the last one)
exchange_rate_columns = df.columns[2:-1]

# Convert exchange rate columns to numeric, coercing errors to NaN
for col in exchange_rate_columns:
    # Check the type of the column data before conversion
    print(f"Processing column: {col}, Type: {type(df[col])}")
    try:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    except TypeError as e:
        print(f"TypeError encountered for column: {col} - {e}")


# Display the data types to verify the conversion
display(df.info())
# Out:
# Processing column: AUSTRALIA - AUSTRALIAN DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: EURO AREA - EURO/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: NEW ZEALAND - NEW ZELAND DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: UNITED KINGDOM - UNITED KINGDOM POUND/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: BRAZIL - REAL/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: CANADA - CANADIAN DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: CHINA - YUAN/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: HONG KONG - HONG KONG DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: INDIA - INDIAN RUPEE/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: KOREA - WON/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: MEXICO - MEXICAN PESO/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: SOUTH AFRICA - RAND/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: SINGAPORE - SINGAPORE DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: DENMARK - DANISH KRONE/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: JAPAN - YEN/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: MALAYSIA - RINGGIT/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: NORWAY - NORWEGIAN KRONE/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: SWEDEN - KRONA/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: SRI LANKA - SRI LANKAN RUPEE/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: SWITZERLAND - FRANC/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: TAIWAN - NEW TAIWAN DOLLAR/US$, Type: <class 'pandas.core.series.Series'>
# Processing column: THAILAND - BAHT/US$, Type: <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5217 entries, 0 to 5216
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0                                              5217 non-null   object
#  1   Time Serie                                 5217 non-null   datetime64[ns]
#  2   AUSTRALIA - AUSTRALIAN DOLLAR/US$          5019 non-null   float64
#  3   EURO AREA - EURO/US$                       5019 non-null   float64
#  4   NEW ZEALAND - NEW ZELAND DOLLAR/US$        5019 non-null   float64
#  5   UNITED KINGDOM - UNITED KINGDOM POUND/US$  5019 non-null   float64
#  6   BRAZIL - REAL/US$                          5019 non-null   float64
#  7   CANADA - CANADIAN DOLLAR/US$               5019 non-null   float64
#  8   CHINA - YUAN/US$                           5020 non-null   float64
#  9   HONG KONG - HONG KONG DOLLAR/US$           5019 non-null   float64
#  10  INDIA - INDIAN RUPEE/US$                   5018 non-null   float64
#  11  KOREA - WON/US$                            5019 non-null   float64
#  12  MEXICO - MEXICAN PESO/US$                  5019 non-null   float64
#  13  SOUTH AFRICA - RAND/US$                    5019 non-null   float64
#  14  SINGAPORE - SINGAPORE DOLLAR/US$           5019 non-null   float64
#  15  DENMARK - DANISH KRONE/US$                 5019 non-null   float64
#  16  JAPAN - YEN/US$                            5019 non-null   float64
#  17  MALAYSIA - RINGGIT/US$                     5019 non-null   float64
#  18  NORWAY - NORWEGIAN KRONE/US$               5019 non-null   float64
#  19  SWEDEN - KRONA/US$                         5019 non-null   float64
#  20  SRI LANKA - SRI LANKAN RUPEE/US$           5019 non-null   float64
#  21  SWITZERLAND - FRANC/US$                    5019 non-null   float64
#  22  TAIWAN - NEW TAIWAN DOLLAR/US$             5016 non-null   float64
#  23  THAILAND - BAHT/US$                        5019 non-null   float64
#  24                                             5217 non-null   object
# dtypes: datetime64[ns](1), float64(22), object(2)
# memory usage: 1019.1+ KB
# None

# %%
# Select a few exchange rate columns to plot
selected_columns = ['EURO AREA - EURO/US$', 'JAPAN - YEN/US$', 'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'CANADA - CANADIAN DOLLAR/US$']

# Set the 'Time Serie' column as the index for plotting
df_plot = df.set_index('Time Serie')

# Plot the selected exchange rates
plt.figure(figsize=(12, 6))
for col in selected_columns:
    plt.plot(df_plot.index, df_plot[col], label=col)

plt.title('Selected Foreign Exchange Rates Over Time')
plt.xlabel('Date')
plt.ylabel('Exchange Rate (vs USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Task
# Compare several time-series forecasting models (ARIMA/SARIMA, Prophet, AutoTS, XGBoost/LightGBM, LSTM) for each currency in the dataset, split the data into training and testing sets (last 60 days as test), train and evaluate each model using MAE, RMSE, and MAPE, and select the best model for each currency.

# %% [markdown]
# ## Prepare data for modeling
#
# ### Subtask:
# Split the data into training and testing sets for each currency.

# %% [markdown]
# **Reasoning**:
# Split the data into training and testing sets for each currency and store them in a dictionary.

# %%
test_size = 60
currency_data = {}

exchange_rate_columns = df.columns[2:-1]

for col in exchange_rate_columns:
    train_data = df[:-test_size].copy()
    test_data = df[-test_size:].copy()
    currency_data[col] = (train_data[['Time Serie', col]], test_data[['Time Serie', col]])

# Display the keys of the currency_data dictionary to show which currencies were processed
print(currency_data.keys())
# Out:
# dict_keys(['AUSTRALIA - AUSTRALIAN DOLLAR/US$', 'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$', 'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$', 'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$', 'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$', 'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$', 'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$', 'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$', 'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$', 'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$', 'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$', 'THAILAND - BAHT/US$'])

# %% [markdown]
# ## Implement and train forecasting models
#
# ### Subtask:
# For each selected model (ARIMA/SARIMA, Prophet, AutoTS, XGBoost/LightGBM, LSTM), train a separate instance for each currency using the training data.

# %% [markdown]
# **Reasoning**:
# Import the necessary libraries for the specified forecasting models.

# %%
from prophet import Prophet
from statsmodels.tsa.arima.model import ARIMA
from autots import AutoTS
import xgboost as xgb
import lightgbm as lgb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# %%
# %pip install autots
# Out:
# Collecting autots
#   Downloading autots-0.6.21-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.11/dist-packages (from autots) (2.0.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from autots) (2.2.2)
# Requirement already satisfied: statsmodels>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from autots) (0.14.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from autots) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.0->autots) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.0->autots) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.0->autots) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->autots) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->autots) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->autots) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.10.0->autots) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.10.0->autots) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.0->autots) (1.17.0)
# Downloading autots-0.6.21-py3-none-any.whl (974 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.9/974.9 kB 14.1 MB/s eta 0:00:00
# Installing collected packages: autots
# Successfully installed autots-0.6.21

# %%
import lightgbm as lgb

# Dictionary to store trained LightGBM models
lightgbm_models = {}

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training LightGBM model for {currency}...")

    # Prepare data for LightGBM
    # LightGBM requires numerical input features. We'll use the timestamp as a feature.
    # We also need to handle potential NaN values.
    lightgbm_train_data = train_data.copy().dropna()

    if not lightgbm_train_data.empty:
        try:
            X_train = lightgbm_train_data['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
            y_train = lightgbm_train_data[currency].values

            # Initialize and fit the LightGBM Regressor model
            model = lgb.LGBMRegressor(objective='regression', n_estimators=100, learning_rate=0.1, num_leaves=31, random_state=42)
            model.fit(X_train, y_train)

            # Store the trained model
            lightgbm_models[currency] = model
        except Exception as e:
            print(f"Could not train LightGBM model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for LightGBM.")

print("LightGBM model training complete for all currencies (where possible).")
# Out:
# LightGBM model training complete for all currencies (where possible).

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import numpy as np

# Dictionary to store trained LSTM models and their scalers
lstm_models = {}
lstm_scalers = {}

# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

# Define sequence length
seq_length = 10

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training LSTM model for {currency}...")

    # Prepare data for LSTM
    # LSTM requires numerical input and is sensitive to scale.
    # We need to handle potential NaN values and scale the data.
    lstm_train_data = train_data.copy().dropna()

    if not lstm_train_data.empty:
        try:
            # Select the currency column and convert to numpy array
            data_to_scale = lstm_train_data[currency].values.reshape(-1, 1)

            # Scale the data
            scaler = MinMaxScaler(feature_range=(0, 1))
            scaled_data = scaler.fit_transform(data_to_scale)

            # Create sequences
            X_train, y_train = create_sequences(scaled_data, seq_length)

            # Reshape input to be [samples, time steps, features]
            X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

            # Build the LSTM model
            model = Sequential()
            model.add(LSTM(50, return_sequences=True, input_shape=(seq_length, 1)))
            model.add(LSTM(50, return_sequences=False))
            model.add(Dense(25))
            model.add(Dense(1))

            # Compile the model
            model.compile(optimizer='adam', loss='mean_squared_error')

            # Train the model
            model.fit(X_train, y_train, batch_size=1, epochs=1) # Reduced epochs for faster execution

            # Store the trained model and scaler
            lstm_models[currency] = model
            lstm_scalers[currency] = scaler

        except Exception as e:
            print(f"Could not train LSTM model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for LSTM.")

print("LSTM model training complete for all currencies (where possible).")
# Out:
# LSTM model training complete for all currencies (where possible).

# %% [markdown]
# Compare the performance of ARIMA/SARIMA, Prophet, AutoTS, XGBoost/LightGBM, and LSTM time-series forecasting models for each currency in the dataset "currency_exchange_rates.csv". For each currency, split the data into training and testing sets (using the last 60 days for testing), train each model, evaluate using MAE, RMSE, and MAPE, and identify the best performing model.

# %% [markdown]
# ## Evaluate models
#
# ### Subtask:
# Forecast using each trained model on its respective test data and calculate MAE, RMSE, and MAPE for each currency and model.

# %% [markdown]
# **Reasoning**:
# Initialise the dictionary to store evaluation results and iterate through each currency to generate forecasts using Prophet, ARIMA, XGBoost, LightGBM, and LSTM models and calculate evaluation metrics.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates the Mean Absolute Percentage Error."""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero by replacing 0 with a small epsilon or handling it
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

evaluation_results = {}

for currency, (train_data, test_data) in currency_data.items():
    print(f"Evaluating models for {currency}...")
    evaluation_results[currency] = {}

    # Extract actual values for the test period
    actual_values = test_data[currency].values

    # Prophet Evaluation
    if currency in prophet_models:
        try:
            model = prophet_models[currency]
            # Prophet requires a future dataframe with 'ds' column
            future = model.make_future_dataframe(periods=len(test_data), freq='D')
            forecast = model.predict(future)

            # Align the forecast with the test data
            prophet_forecast = forecast[['ds', 'yhat']].set_index('ds').reindex(test_data['Time Serie']).dropna()['yhat'].values
            prophet_actual = test_data.set_index('Time Serie').reindex(test_data['Time Serie']).dropna()[currency].values

            if len(prophet_actual) > 0 and len(prophet_forecast) == len(prophet_actual):
                mae = mean_absolute_error(prophet_actual, prophet_forecast)
                rmse = np.sqrt(mean_squared_error(prophet_actual, prophet_forecast))
                mape = mean_absolute_percentage_error(prophet_actual, prophet_forecast)
                evaluation_results[currency]['Prophet'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Prophet forecast length mismatch or no valid data for {currency}")
                 evaluation_results[currency]['Prophet'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating Prophet for {currency}: {e}")
            evaluation_results[currency]['Prophet'] = 'Evaluation Failed'


    # ARIMA Evaluation
    if currency in arima_models:
        try:
            model_fit = arima_models[currency]
            # Forecast for the length of the test data
            arima_forecast = model_fit.forecast(steps=len(test_data))

            # Align the forecast with the test data
            arima_actual = test_data[currency].values

            # Handle potential index mismatch if ARIMA forecast has different index
            if len(arima_forecast) == len(arima_actual):
                mae = mean_absolute_error(arima_actual, arima_forecast)
                rmse = np.sqrt(mean_squared_error(arima_actual, arima_forecast))
                mape = mean_absolute_percentage_error(arima_actual, arima_forecast)
                evaluation_results[currency]['ARIMA'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"ARIMA forecast length mismatch for {currency}")
                 evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating ARIMA for {currency}: {e}")
            evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'

    # XGBoost Evaluation
    if currency in xgboost_models:
        try:
            model = xgboost_models[currency]
            # Prepare test data
            xgboost_test_data = test_data.copy().dropna()
            if not xgboost_test_data.empty:
                X_test = xgboost_test_data['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = xgboost_test_data[currency].values

                xgboost_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, xgboost_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, xgboost_predictions))
                mape = mean_absolute_percentage_error(y_test, xgboost_predictions)
                evaluation_results[currency]['XGBoost'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for XGBoost evaluation.")
                 evaluation_results[currency]['XGBoost'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating XGBoost for {currency}: {e}")
            evaluation_results[currency]['XGBoost'] = 'Evaluation Failed'

    # LightGBM Evaluation
    if currency in lightgbm_models:
        try:
            model = lightgbm_models[currency]
            # Prepare test data
            lightgbm_test_data = test_data.copy().dropna()
            if not lightgbm_test_data.empty:
                X_test = lightgbm_test_data['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = lightgbm_test_data[currency].values

                lightgbm_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, lightgbm_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, lightgbm_predictions))
                mape = mean_absolute_percentage_error(y_test, lightgbm_predictions)
                evaluation_results[currency]['LightGBM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for LightGBM evaluation.")
                 evaluation_results[currency]['LightGBM'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating LightGBM for {currency}: {e}")
            evaluation_results[currency]['LightGBM'] = 'Evaluation Failed'

    # LSTM Evaluation
    if currency in lstm_models and currency in lstm_scalers:
        try:
            model = lstm_models[currency]
            scaler = lstm_scalers[currency]

            # Prepare test data for LSTM
            lstm_test_data = test_data.copy().dropna()
            if len(lstm_test_data) >= seq_length:
                 data_to_scale = lstm_test_data[currency].values.reshape(-1, 1)
                 scaled_data = scaler.transform(data_to_scale)

                 X_test, y_test_scaled = create_sequences(scaled_data, seq_length)
                 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

                 lstm_predictions_scaled = model.predict(X_test)
                 lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
                 y_test = scaler.inverse_transform(y_test_scaled.reshape(-1, 1)) # Inverse transform actuals

                 mae = mean_absolute_error(y_test, lstm_predictions)
                 rmse = np.sqrt(mean_squared_error(y_test, lstm_predictions))
                 mape = mean_absolute_percentage_error(y_test, lstm_predictions)
                 evaluation_results[currency]['LSTM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is too short for LSTM evaluation (requires at least {seq_length} data points).")
                 evaluation_results[currency]['LSTM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LSTM for {currency}: {e}")
            evaluation_results[currency]['LSTM'] = 'Evaluation Failed'

    # AutoTS Evaluation (Placeholder - needs implementation based on AutoTS forecasting)
    # Assuming AutoTS forecasts are stored in a dictionary called autots_forecasts
    # if currency in autots_forecasts:
    #     try:
    #         autots_predictions = autots_forecasts[currency] # This needs to be defined based on how AutoTS is used
    #         # Ensure the length of predictions matches the test data length
    #         if len(autots_predictions) == len(actual_values):
    #             mae = mean_absolute_error(actual_values, autots_predictions)
    #             rmse = np.sqrt(mean_squared_error(actual_values, autots_predictions))
    #             mape = mean_absolute_percentage_error(actual_values, autots_predictions)
    #             evaluation_results[currency]['AutoTS'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
    #         else:
    #             print(f"AutoTS forecast length mismatch for {currency}")
    #             evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'
    #     except Exception as e:
    #         print(f"Error evaluating AutoTS for {currency}: {e}")
    #         evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'


# Print the evaluation results
import json
print(json.dumps(evaluation_results, indent=4))
# Out:
# {}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reasoning**:
# The necessary libraries have been imported. Now I need to re-run the data loading and preprocessing steps to define the `df` DataFrame and prepare it for splitting and model training.

# %%
# Load the data into a single column, skipping initial metadata if any
# Based on previous output, it seems the actual data starts from row 1 (index 0)
df = pd.read_excel("Foreign_Exchange_Rates.xlsx", header=None)

# The data is in the first column (index 0) and is comma-separated
# Split the single column into multiple columns based on the comma delimiter
df = df[0].str.split(',', expand=True)

# The first row of the split dataframe contains the column names
column_names = df.iloc[0].tolist()

# Assign the column names
df.columns = column_names

# Remove the header row from the data
df = df[1:].reset_index(drop=True)

# Convert the 'Time Serie' column to a datetime format
df['Time Serie'] = pd.to_datetime(df['Time Serie'], dayfirst=True, errors='coerce')

# Replace 'ND' values with NaN
df.replace('ND', np.nan, inplace=True)

# Identify exchange rate columns (all except the first two and the last one)
exchange_rate_columns = df.columns[2:-1]

# Convert exchange rate columns to numeric, coercing errors to NaN
for col in exchange_rate_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Display the first few rows and the columns to verify
display(df.head())
display(df.columns)
display(df.info())
# Out:
#      Time Serie  AUSTRALIA - AUSTRALIAN DOLLAR/US$  EURO AREA - EURO/US$  \
# 0  0 2000-01-03                             1.5172                0.9847
# 1  1 2000-01-04                             1.5239                0.9700
# 2  2 2000-01-05                             1.5267                0.9676
# 3  3 2000-01-06                             1.5291                0.9686
# 4  4 2000-01-07                             1.5272                0.9714
#
#    NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                               1.9033
# 1                               1.9238
# 2                               1.9339
# 3                               1.9436
# 4                               1.9380
#
#    UNITED KINGDOM - UNITED KINGDOM POUND/US$  BRAZIL - REAL/US$  \
# 0                                     0.6146             1.8050
# 1                                     0.6109             1.8405
# 2                                     0.6092             1.8560
# 3                                     0.6070             1.8400
# 4                                     0.6104             1.8310
#
#    CANADA - CANADIAN DOLLAR/US$  CHINA - YUAN/US$  \
# 0                        1.4465            8.2798
# 1                        1.4518            8.2799
# 2                        1.4518            8.2798
# 3                        1.4571            8.2797
# 4                        1.4505            8.2794
#
#    HONG KONG - HONG KONG DOLLAR/US$  ...  DENMARK - DANISH KRONE/US$  \
# 0                            7.7765  ...                      7.3290
# 1                            7.7775  ...                      7.2180
# 2                            7.7780  ...                      7.2080
# 3                            7.7785  ...                      7.2125
# 4                            7.7783  ...                      7.2285
#
#    JAPAN - YEN/US$  MALAYSIA - RINGGIT/US$  NORWAY - NORWEGIAN KRONE/US$  \
# 0           101.70                     3.8                         7.964
# 1           103.09                     3.8                         7.934
# 2           103.77                     3.8                         7.935
# 3           105.19                     3.8                         7.940
# 4           105.17                     3.8                         7.966
#
#    SWEDEN - KRONA/US$  SRI LANKA - SRI LANKAN RUPEE/US$  \
# 0              8.4430                             72.30
# 1              8.3600                             72.65
# 2              8.3530                             72.95
# 3              8.3675                             72.95
# 4              8.4150                             73.15
#
#    SWITZERLAND - FRANC/US$  TAIWAN - NEW TAIWAN DOLLAR/US$  \
# 0                   1.5808                           31.38
# 1                   1.5565                           30.60
# 2                   1.5526                           30.80
# 3                   1.5540                           31.75
# 4                   1.5623                           30.85
#
#    THAILAND - BAHT/US$
# 0                36.97
# 1                37.13
# 2                37.10
# 3                37.62
# 4                37.30
#
# [5 rows x 25 columns]
# Index(['', 'Time Serie', 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
#        'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
#        'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$',
#        'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$',
#        'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$',
#        'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$',
#        'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$',
#        'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$',
#        'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$',
#        'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$',
#        'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$',
#        'THAILAND - BAHT/US$', ''],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5217 entries, 0 to 5216
# Data columns (total 25 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0                                              5217 non-null   object
#  1   Time Serie                                 5217 non-null   datetime64[ns]
#  2   AUSTRALIA - AUSTRALIAN DOLLAR/US$          5019 non-null   float64
#  3   EURO AREA - EURO/US$                       5019 non-null   float64
#  4   NEW ZEALAND - NEW ZELAND DOLLAR/US$        5019 non-null   float64
#  5   UNITED KINGDOM - UNITED KINGDOM POUND/US$  5019 non-null   float64
#  6   BRAZIL - REAL/US$                          5019 non-null   float64
#  7   CANADA - CANADIAN DOLLAR/US$               5019 non-null   float64
#  8   CHINA - YUAN/US$                           5020 non-null   float64
#  9   HONG KONG - HONG KONG DOLLAR/US$           5019 non-null   float64
#  10  INDIA - INDIAN RUPEE/US$                   5018 non-null   float64
#  11  KOREA - WON/US$                            5019 non-null   float64
#  12  MEXICO - MEXICAN PESO/US$                  5019 non-null   float64
#  13  SOUTH AFRICA - RAND/US$                    5019 non-null   float64
#  14  SINGAPORE - SINGAPORE DOLLAR/US$           5019 non-null   float64
#  15  DENMARK - DANISH KRONE/US$                 5019 non-null   float64
#  16  JAPAN - YEN/US$                            5019 non-null   float64
#  17  MALAYSIA - RINGGIT/US$                     5019 non-null   float64
#  18  NORWAY - NORWEGIAN KRONE/US$               5019 non-null   float64
#  19  SWEDEN - KRONA/US$                         5019 non-null   float64
#  20  SRI LANKA - SRI LANKAN RUPEE/US$           5019 non-null   float64
#  21  SWITZERLAND - FRANC/US$                    5019 non-null   float64
#  22  TAIWAN - NEW TAIWAN DOLLAR/US$             5016 non-null   float64
#  23  THAILAND - BAHT/US$                        5019 non-null   float64
#  24                                             5217 non-null   object
# dtypes: datetime64[ns](1), float64(22), object(2)
# memory usage: 1019.1+ KB
# None

# %% [markdown]
# **Reasoning**:
# The data loading and preprocessing steps were successful, and the `df` DataFrame is now available and cleaned. The next step is to re-run the code to split the data into training and testing sets for each currency and populate the `currency_data` dictionary.

# %%
test_size = 60
currency_data = {}

exchange_rate_columns = df.columns[2:-1]

for col in exchange_rate_columns:
    train_data = df[:-test_size].copy()
    test_data = df[-test_size:].copy()
    currency_data[col] = (train_data[['Time Serie', col]], test_data[['Time Serie', col]])

# Display the keys of the currency_data dictionary to show which currencies were processed
print(currency_data.keys())
# Out:
# dict_keys(['AUSTRALIA - AUSTRALIAN DOLLAR/US$', 'EURO AREA - EURO/US$', 'NEW ZEALAND - NEW ZELAND DOLLAR/US$', 'UNITED KINGDOM - UNITED KINGDOM POUND/US$', 'BRAZIL - REAL/US$', 'CANADA - CANADIAN DOLLAR/US$', 'CHINA - YUAN/US$', 'HONG KONG - HONG KONG DOLLAR/US$', 'INDIA - INDIAN RUPEE/US$', 'KOREA - WON/US$', 'MEXICO - MEXICAN PESO/US$', 'SOUTH AFRICA - RAND/US$', 'SINGAPORE - SINGAPORE DOLLAR/US$', 'DENMARK - DANISH KRONE/US$', 'JAPAN - YEN/US$', 'MALAYSIA - RINGGIT/US$', 'NORWAY - NORWEGIAN KRONE/US$', 'SWEDEN - KRONA/US$', 'SRI LANKA - SRI LANKAN RUPEE/US$', 'SWITZERLAND - FRANC/US$', 'TAIWAN - NEW TAIWAN DOLLAR/US$', 'THAILAND - BAHT/US$'])

# %% [markdown]
# **Reasoning**:
# The `currency_data` dictionary is now populated with the training and testing data for each currency. I need to re-run the model training for Prophet, ARIMA, XGBoost, LightGBM, and LSTM models before attempting evaluation again.

# %%
from prophet import Prophet
from statsmodels.tsa.arima.model import ARIMA
# AutoTS will be skipped for now as its forecasting method in this context is unclear from previous steps.
import xgboost as xgb
import lightgbm as lgb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Dictionary to store trained Prophet models
prophet_models = {}

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training Prophet model for {currency}...")

    # Prophet requires columns to be named 'ds' and 'y'
    prophet_train_data = train_data.rename(columns={'Time Serie': 'ds', currency: 'y'}).dropna()

    if not prophet_train_data.empty:
        try:
            # Initialize and fit the Prophet model
            model = Prophet()
            model.fit(prophet_train_data)

            # Store the trained model
            prophet_models[currency] = model
        except Exception as e:
            print(f"Could not train Prophet model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for Prophet.")

print("Prophet model training complete for all currencies.")

# Dictionary to store trained ARIMA models
arima_models = {}

# Define a basic order for ARIMA (p, d, q) - this might need tuning
arima_order = (5, 1, 0)

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training ARIMA model for {currency}...")

    # ARIMA requires a Series with a DatetimeIndex
    # We need to handle potential NaN values in the training data for ARIMA
    arima_train_data = train_data.set_index('Time Serie')[currency].dropna()

    if not arima_train_data.empty:
        try:
            # Initialize and fit the ARIMA model
            model = ARIMA(arima_train_data, order=arima_order)
            model_fit = model.fit()

            # Store the trained model
            arima_models[currency] = model_fit
        except Exception as e:
            print(f"Could not train ARIMA model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for ARIMA.")

print("ARIMA model training complete for all currencies (where possible).")

# Dictionary to store trained XGBoost models
xgboost_models = {}

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training XGBoost model for {currency}...")

    # Prepare data for XGBoost
    # XGBoost requires numerical input features. We'll use the timestamp as a feature.
    # We also need to handle potential NaN values.
    xgboost_train_data = train_data.copy().dropna()

    if not xgboost_train_data.empty:
        try:
            X_train = xgboost_train_data['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
            y_train = xgboost_train_data[currency].values

            # Initialize and fit the XGBoost Regressor model
            model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42)
            model.fit(X_train, y_train)

            # Store the trained model
            xgboost_models[currency] = model
        except Exception as e:
            print(f"Could not train XGBoost model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for XGBoost.")

print("XGBoost model training complete for all currencies (where possible).")

# Dictionary to store trained LightGBM models
lightgbm_models = {}

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training LightGBM model for {currency}...")

    # Prepare data for LightGBM
    # LightGBM requires numerical input features. We'll use the timestamp as a feature.
    # We also need to handle potential NaN values.
    lightgbm_train_data = train_data.copy().dropna()

    if not lightgbm_train_data.empty:
        try:
            X_train = lightgbm_train_data['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
            y_train = lightgbm_train_data[currency].values

            # Initialize and fit the LightGBM Regressor model
            model = lgb.LGBMRegressor(objective='regression', n_estimators=100, learning_rate=0.1, num_leaves=31, random_state=42)
            model.fit(X_train, y_train)

            # Store the trained model
            lightgbm_models[currency] = model
        except Exception as e:
            print(f"Could not train LightGBM model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for LightGBM.")

print("LightGBM model training complete for all currencies (where possible).")

# Dictionary to store trained LSTM models and their scalers
lstm_models = {}
lstm_scalers = {}

# Function to create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

# Define sequence length
seq_length = 10

for currency, (train_data, test_data) in currency_data.items():
    print(f"Training LSTM model for {currency}...")

    # Prepare data for LSTM
    # LSTM requires numerical input and is sensitive to scale.
    # We need to handle potential NaN values and scale the data.
    lstm_train_data = train_data.copy().dropna()

    if not lstm_train_data.empty:
        try:
            # Select the currency column and convert to numpy array
            data_to_scale = lstm_train_data[currency].values.reshape(-1, 1)

            # Scale the data
            scaler = MinMaxScaler(feature_range=(0, 1))
            scaled_data = scaler.fit_transform(data_to_scale)

            # Create sequences
            if len(scaled_data) >= seq_length + 1: # Ensure enough data for at least one sequence
                X_train, y_train = create_sequences(scaled_data, seq_length)

                # Reshape input to be [samples, time steps, features]
                X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

                # Build the LSTM model
                model = Sequential()
                model.add(LSTM(50, return_sequences=True, input_shape=(seq_length, 1)))
                model.add(LSTM(50, return_sequences=False))
                model.add(Dense(25))
                model.add(Dense(1))

                # Compile the model
                model.compile(optimizer='adam', loss='mean_squared_error')

                # Train the model
                model.fit(X_train, y_train, batch_size=1, epochs=1, verbose=0) # Reduced epochs and verbosity

                # Store the trained model and scaler
                lstm_models[currency] = model
                lstm_scalers[currency] = scaler
            else:
                 print(f"Training data for {currency} is too short for LSTM sequence creation (requires at least {seq_length + 1} data points).")
                 evaluation_results[currency]['LSTM'] = 'Training Failed - Insufficient Data'


        except Exception as e:
            print(f"Could not train LSTM model for {currency}: {e}")
    else:
        print(f"Training data for {currency} is empty after dropping NaNs for LSTM.")

print("LSTM model training complete for all currencies (where possible).")
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/q6vkxh1l.json
# Training Prophet model for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/kmpxhwao.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84207', 'data', 'file=/tmp/tmpw_274jvu/q6vkxh1l.json', 'init=/tmp/tmpw_274jvu/kmpxhwao.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelieg66rlh/prophet_model-20250725223537.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/gkm678le.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/8h4ex8ed.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17341', 'data', 'file=/tmp/tmpw_274jvu/gkm678le.json', 'init=/tmp/tmpw_274jvu/8h4ex8ed.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modeluuung_op/prophet_model-20250725223539.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for EURO AREA - EURO/US$...
# 22:35:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/q0vqy0j_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/foirrs16.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6486', 'data', 'file=/tmp/tmpw_274jvu/q0vqy0j_.json', 'init=/tmp/tmpw_274jvu/foirrs16.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model9ifqqmso/prophet_model-20250725223541.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# Training Prophet model for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# 22:35:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/703n7gz2.json
# Training Prophet model for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/ho8wja9f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77023', 'data', 'file=/tmp/tmpw_274jvu/703n7gz2.json', 'init=/tmp/tmpw_274jvu/ho8wja9f.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modellrum9rbn/prophet_model-20250725223544.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/96sjfvas.json
# Training Prophet model for BRAZIL - REAL/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/d4r7qc9a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72922', 'data', 'file=/tmp/tmpw_274jvu/96sjfvas.json', 'init=/tmp/tmpw_274jvu/d4r7qc9a.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelldf_1zoe/prophet_model-20250725223546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/ozko_qnu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/qx555azn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78636', 'data', 'file=/tmp/tmpw_274jvu/ozko_qnu.json', 'init=/tmp/tmpw_274jvu/qx555azn.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modellmyvz7w6/prophet_model-20250725223547.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for CANADA - CANADIAN DOLLAR/US$...
# 22:35:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/dbp9k96m.json
# Training Prophet model for CHINA - YUAN/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/gfo1_j60.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30677', 'data', 'file=/tmp/tmpw_274jvu/dbp9k96m.json', 'init=/tmp/tmpw_274jvu/gfo1_j60.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelrnt_ycpb/prophet_model-20250725223550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/y6kbieqk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/qh8c7hhf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25484', 'data', 'file=/tmp/tmpw_274jvu/y6kbieqk.json', 'init=/tmp/tmpw_274jvu/qh8c7hhf.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model0fcduenx/prophet_model-20250725223552.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for HONG KONG - HONG KONG DOLLAR/US$...
# 22:35:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Training Prophet model for INDIA - INDIAN RUPEE/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/bq9a3zcm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/zvrj70tm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88906', 'data', 'file=/tmp/tmpw_274jvu/bq9a3zcm.json', 'init=/tmp/tmpw_274jvu/zvrj70tm.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelo198bwsk/prophet_model-20250725223554.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/xrgv_pof.json
# Training Prophet model for KOREA - WON/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/2l_op5pe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66186', 'data', 'file=/tmp/tmpw_274jvu/xrgv_pof.json', 'init=/tmp/tmpw_274jvu/2l_op5pe.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_models_970na2/prophet_model-20250725223556.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:35:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/0i70jl0h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/tr0vsdcu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27791', 'data', 'file=/tmp/tmpw_274jvu/0i70jl0h.json', 'init=/tmp/tmpw_274jvu/tr0vsdcu.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modeltjbic5a2/prophet_model-20250725223559.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:35:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for MEXICO - MEXICAN PESO/US$...
# 22:36:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/m3yr__kt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/d8f661xy.json
# Training Prophet model for SOUTH AFRICA - RAND/US$...
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39628', 'data', 'file=/tmp/tmpw_274jvu/m3yr__kt.json', 'init=/tmp/tmpw_274jvu/d8f661xy.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modell0vmrpdc/prophet_model-20250725223600.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/_tvp6kq6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/3mceq75p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15507', 'data', 'file=/tmp/tmpw_274jvu/_tvp6kq6.json', 'init=/tmp/tmpw_274jvu/3mceq75p.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model3m_ym4q_/prophet_model-20250725223602.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for SINGAPORE - SINGAPORE DOLLAR/US$...
# 22:36:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/mnzt0y51.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/u5wvq5ni.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56406', 'data', 'file=/tmp/tmpw_274jvu/mnzt0y51.json', 'init=/tmp/tmpw_274jvu/u5wvq5ni.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelr2aoxr4s/prophet_model-20250725223604.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for DENMARK - DANISH KRONE/US$...
# 22:36:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/5mjbdka2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/emdt5pe7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62555', 'data', 'file=/tmp/tmpw_274jvu/5mjbdka2.json', 'init=/tmp/tmpw_274jvu/emdt5pe7.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelpl_4vnye/prophet_model-20250725223606.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for JAPAN - YEN/US$...
# 22:36:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/ysnpb7iq.json
# Training Prophet model for MALAYSIA - RINGGIT/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/goehmpum.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95319', 'data', 'file=/tmp/tmpw_274jvu/ysnpb7iq.json', 'init=/tmp/tmpw_274jvu/goehmpum.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelw_u2tv_p/prophet_model-20250725223608.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/1h4dooc3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/dyczwdra.json
# DEBUG:cmdstanpy:idx 0
# Training Prophet model for NORWAY - NORWEGIAN KRONE/US$...
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29976', 'data', 'file=/tmp/tmpw_274jvu/1h4dooc3.json', 'init=/tmp/tmpw_274jvu/dyczwdra.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model3jif1a7u/prophet_model-20250725223610.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/4p52n9mh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/i9077gkp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50607', 'data', 'file=/tmp/tmpw_274jvu/4p52n9mh.json', 'init=/tmp/tmpw_274jvu/i9077gkp.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model7qpc5z9t/prophet_model-20250725223612.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for SWEDEN - KRONA/US$...
# 22:36:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/6wzjpfq0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/zl7_0qgk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# Training Prophet model for SRI LANKA - SRI LANKAN RUPEE/US$...
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82833', 'data', 'file=/tmp/tmpw_274jvu/6wzjpfq0.json', 'init=/tmp/tmpw_274jvu/zl7_0qgk.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modeld_6v8jzl/prophet_model-20250725223614.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/z5dg5b0f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/fw_vt067.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3581', 'data', 'file=/tmp/tmpw_274jvu/z5dg5b0f.json', 'init=/tmp/tmpw_274jvu/fw_vt067.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modelyhpn_fwc/prophet_model-20250725223616.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Training Prophet model for SWITZERLAND - FRANC/US$...
# 22:36:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/2u3isn6p.json
# Training Prophet model for TAIWAN - NEW TAIWAN DOLLAR/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/ms_zysxz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29138', 'data', 'file=/tmp/tmpw_274jvu/2u3isn6p.json', 'init=/tmp/tmpw_274jvu/ms_zysxz.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_model3x78bprz/prophet_model-20250725223618.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/x0vb_yf0.json
# Training Prophet model for THAILAND - BAHT/US$...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpw_274jvu/5hto3w53.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66426', 'data', 'file=/tmp/tmpw_274jvu/x0vb_yf0.json', 'init=/tmp/tmpw_274jvu/5hto3w53.json', 'output', 'file=/tmp/tmpw_274jvu/prophet_modeldupp88z5/prophet_model-20250725223620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Prophet model training complete for all currencies.
# Training ARIMA model for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# Training ARIMA model for EURO AREA - EURO/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for BRAZIL - REAL/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for CANADA - CANADIAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for CHINA - YUAN/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for HONG KONG - HONG KONG DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for INDIA - INDIAN RUPEE/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for KOREA - WON/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for MEXICO - MEXICAN PESO/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for SOUTH AFRICA - RAND/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for SINGAPORE - SINGAPORE DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for DENMARK - DANISH KRONE/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for JAPAN - YEN/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for MALAYSIA - RINGGIT/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for NORWAY - NORWEGIAN KRONE/US$...
# Training ARIMA model for SWEDEN - KRONA/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for SRI LANKA - SRI LANKAN RUPEE/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for SWITZERLAND - FRANC/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for TAIWAN - NEW TAIWAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Training ARIMA model for THAILAND - BAHT/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA model training complete for all currencies (where possible).
# Training XGBoost model for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# Training XGBoost model for EURO AREA - EURO/US$...
# Training XGBoost model for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# Training XGBoost model for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# Training XGBoost model for BRAZIL - REAL/US$...
# Training XGBoost model for CANADA - CANADIAN DOLLAR/US$...
# Training XGBoost model for CHINA - YUAN/US$...
# Training XGBoost model for HONG KONG - HONG KONG DOLLAR/US$...
# Training XGBoost model for INDIA - INDIAN RUPEE/US$...
# Training XGBoost model for KOREA - WON/US$...
# Training XGBoost model for MEXICO - MEXICAN PESO/US$...
# Training XGBoost model for SOUTH AFRICA - RAND/US$...
# Training XGBoost model for SINGAPORE - SINGAPORE DOLLAR/US$...
# Training XGBoost model for DENMARK - DANISH KRONE/US$...
# Training XGBoost model for JAPAN - YEN/US$...
# Training XGBoost model for MALAYSIA - RINGGIT/US$...
# Training XGBoost model for NORWAY - NORWEGIAN KRONE/US$...
# Training XGBoost model for SWEDEN - KRONA/US$...
# Training XGBoost model for SRI LANKA - SRI LANKAN RUPEE/US$...
# Training XGBoost model for SWITZERLAND - FRANC/US$...
# Training XGBoost model for TAIWAN - NEW TAIWAN DOLLAR/US$...
# Training XGBoost model for THAILAND - BAHT/US$...
# XGBoost model training complete for all currencies (where possible).
# Training LightGBM model for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1.330568
# Training LightGBM model for EURO AREA - EURO/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 0.843249
# Training LightGBM model for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1.543632
# Training LightGBM model for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 0.638877
# Training LightGBM model for BRAZIL - REAL/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 2.530264
# Training LightGBM model for CANADA - CANADIAN DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1.229343
# Training LightGBM model for CHINA - YUAN/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4964, number of used features: 1
# [LightGBM] [Info] Start training from score 7.202703
# Training LightGBM model for HONG KONG - HONG KONG DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 7.782182
# Training LightGBM model for INDIA - INDIAN RUPEE/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4962, number of used features: 1
# [LightGBM] [Info] Start training from score 52.509675
# Training LightGBM model for KOREA - WON/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1124.905174
# Training LightGBM model for MEXICO - MEXICAN PESO/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 13.125935
# Training LightGBM model for SOUTH AFRICA - RAND/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 9.361314
# Training LightGBM model for SINGAPORE - SINGAPORE DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1.481746
# Training LightGBM model for DENMARK - DANISH KRONE/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 6.280881
# Training LightGBM model for JAPAN - YEN/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 106.564596
# Training LightGBM model for MALAYSIA - RINGGIT/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 3.645197
# Training LightGBM model for NORWAY - NORWEGIAN KRONE/US$...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000072 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 7.051930
# Training LightGBM model for SWEDEN - KRONA/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 7.879891
# Training LightGBM model for SRI LANKA - SRI LANKAN RUPEE/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 118.413730
# Training LightGBM model for SWITZERLAND - FRANC/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 1.152285
# Training LightGBM model for TAIWAN - NEW TAIWAN DOLLAR/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4960, number of used features: 1
# [LightGBM] [Info] Start training from score 31.779966
# Training LightGBM model for THAILAND - BAHT/US$...
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000041 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 255
# [LightGBM] [Info] Number of data points in the train set: 4963, number of used features: 1
# [LightGBM] [Info] Start training from score 35.579478
# LightGBM model training complete for all currencies (where possible).
# Training LSTM model for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for EURO AREA - EURO/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for BRAZIL - REAL/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for CANADA - CANADIAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for CHINA - YUAN/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for HONG KONG - HONG KONG DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for INDIA - INDIAN RUPEE/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for KOREA - WON/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for MEXICO - MEXICAN PESO/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for SOUTH AFRICA - RAND/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for SINGAPORE - SINGAPORE DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for DENMARK - DANISH KRONE/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for JAPAN - YEN/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for MALAYSIA - RINGGIT/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for NORWAY - NORWEGIAN KRONE/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for SWEDEN - KRONA/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for SRI LANKA - SRI LANKAN RUPEE/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for SWITZERLAND - FRANC/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for TAIWAN - NEW TAIWAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training LSTM model for THAILAND - BAHT/US$...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# LSTM model training complete for all currencies (where possible).

# %% [markdown]
# ## Evaluate models
#
# ### Subtask:
# Forecast using each trained model on its respective test data and calculate MAE, RMSE, and MAPE for each currency and model.

# %% [markdown]
# **Reasoning**:
# Iterate through each currency, forecast using each trained model, calculate evaluation metrics (MAE, RMSE, MAPE) on the test data, and store the results.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import json

# Function to calculate Mean Absolute Percentage Error
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates the Mean Absolute Percentage Error."""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero by replacing 0 with a small epsilon or handling
    # cases where y_true is zero.
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

evaluation_results = {}

# Iterate through each currency in currency_data
for currency, (train_data, test_data) in currency_data.items():
    print(f"Evaluating models for {currency}...")
    evaluation_results[currency] = {}

    # Extract actual values for the test period, dropping NaNs for evaluation consistency
    # across models that handle NaNs differently.
    test_data_cleaned = test_data.copy().dropna()
    actual_values = test_data_cleaned[currency].values
    test_dates = test_data_cleaned['Time Serie']

    # Prophet Evaluation
    if currency in prophet_models:
        try:
            model = prophet_models[currency]
            # Prophet requires a future dataframe with 'ds' column for forecasting
            future = pd.DataFrame({'ds': test_dates})
            forecast = model.predict(future)

            # Align the forecast with the cleaned test data's dates
            prophet_forecast = forecast.set_index('ds').reindex(test_dates)['yhat'].values

            if len(actual_values) > 0 and len(prophet_forecast) == len(actual_values):
                mae = mean_absolute_error(actual_values, prophet_forecast)
                rmse = np.sqrt(mean_squared_error(actual_values, prophet_forecast))
                mape = mean_absolute_percentage_error(actual_values, prophet_forecast)
                evaluation_results[currency]['Prophet'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Prophet forecast alignment issue or no valid data for {currency}")
                 evaluation_results[currency]['Prophet'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating Prophet for {currency}: {e}")
            evaluation_results[currency]['Prophet'] = 'Evaluation Failed'


    # ARIMA Evaluation
    if currency in arima_models:
        try:
            model_fit = arima_models[currency]
            # Forecast for the dates in the cleaned test data
            # ARIMA's forecast method can take start and end dates or steps
            # Using start and end dates from the cleaned test data for better alignment
            if not test_dates.empty:
                arima_forecast = model_fit.predict(start=test_dates.min(), end=test_dates.max())

                # Align ARIMA forecast with the actual values based on date index
                # Reindexing might be needed if ARIMA's dates don't exactly match test_dates
                arima_forecast_aligned = pd.Series(arima_forecast, index=arima_forecast.index).reindex(test_dates).values

                # Drop NaNs that might result from reindexing if there are missing dates in the forecast
                valid_indices = ~np.isnan(arima_forecast_aligned) & ~np.isnan(actual_values)
                arima_actual_filtered = actual_values[valid_indices]
                arima_forecast_filtered = arima_forecast_aligned[valid_indices]


                if len(arima_actual_filtered) > 0 and len(arima_forecast_filtered) == len(arima_actual_filtered):
                    mae = mean_absolute_error(arima_actual_filtered, arima_forecast_filtered)
                    rmse = np.sqrt(mean_squared_error(arima_actual_filtered, arima_forecast_filtered))
                    mape = mean_absolute_percentage_error(arima_actual_filtered, arima_forecast_filtered)
                    evaluation_results[currency]['ARIMA'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
                else:
                     print(f"ARIMA forecast alignment issue or no valid data for {currency}")
                     evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for ARIMA evaluation.")
                 evaluation_results[currency]['ARIMA'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating ARIMA for {currency}: {e}")
            evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'

    # XGBoost Evaluation
    if currency in xgboost_models:
        try:
            model = xgboost_models[currency]
            # Prepare test data for XGBoost (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                xgboost_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, xgboost_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, xgboost_predictions))
                mape = mean_absolute_percentage_error(y_test, xgboost_predictions)
                evaluation_results[currency]['XGBoost'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for XGBoost evaluation.")
                 evaluation_results[currency]['XGBoost'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating XGBoost for {currency}: {e}")
            evaluation_results[currency]['XGBoost'] = 'Evaluation Failed'

    # LightGBM Evaluation
    if currency in lightgbm_models:
        try:
            model = lightgbm_models[currency]
            # Prepare test data for LightGBM (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                lightgbm_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, lightgbm_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, lightgbm_predictions))
                mape = mean_absolute_percentage_error(y_test, lightgbm_predictions)
                evaluation_results[currency]['LightGBM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for LightGBM evaluation.")
                 evaluation_results[currency]['LightGBM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LightGBM for {currency}: {e}")
            evaluation_results[currency]['LightGBM'] = 'Evaluation Failed'

    # LSTM Evaluation
    if currency in lstm_models and currency in lstm_scalers:
        try:
            model = lstm_models[currency]
            scaler = lstm_scalers[currency]

            # Prepare test data for LSTM (using cleaned data)
            # LSTM needs sequential data, so we need to process the cleaned test data
            lstm_test_data_values = test_data_cleaned[currency].values.reshape(-1, 1)

            if len(lstm_test_data_values) >= seq_length:
                 scaled_test_data = scaler.transform(lstm_test_data_values)

                 # Create sequences for the test data
                 X_test, y_test_scaled = create_sequences(scaled_test_data, seq_length)
                 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

                 lstm_predictions_scaled = model.predict(X_test, verbose=0) # Reduce verbosity
                 lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
                 y_test = scaler.inverse_transform(y_test_scaled.reshape(-1, 1)) # Inverse transform actuals

                 mae = mean_absolute_error(y_test, lstm_predictions)
                 rmse = np.sqrt(mean_squared_error(y_test, lstm_predictions))
                 mape = mean_absolute_percentage_error(y_test, lstm_predictions)
                 evaluation_results[currency]['LSTM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is too short for LSTM evaluation (requires at least {seq_length} data points after dropping NaNs).")
                 evaluation_results[currency]['LSTM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LSTM for {currency}: {e}")
            evaluation_results[currency]['LSTM'] = 'Evaluation Failed'

    # AutoTS Evaluation (Placeholder - needs implementation based on AutoTS forecasting)
    # If AutoTS was trained and forecasts were generated, evaluate here.
    # Example: if 'autots_forecasts' dictionary exists with currency as key
    # if currency in autots_forecasts:
    #     try:
    #         autots_predictions = autots_forecasts[currency] # Needs to be defined
    #         # Align AutoTS forecasts with cleaned test data
    #         # This depends on how AutoTS forecasts are generated and indexed
    #         # Assuming autots_forecasts is a Series or DataFrame with a datetime index
    #         autots_predictions_aligned = autots_predictions.reindex(test_dates).dropna().values
    #         autots_actual_filtered = actual_values[~np.isnan(autots_predictions_aligned)]
    #         autots_predictions_filtered = autots_predictions_aligned[~np.isnan(autots_predictions_aligned)]

    #         if len(autots_actual_filtered) > 0 and len(autots_predictions_filtered) == len(autots_actual_filtered):
    #             mae = mean_absolute_error(autots_actual_filtered, autots_predictions_filtered)
    #             rmse = np.sqrt(mean_squared_error(autots_actual_filtered, autots_predictions_filtered))
    #             mape = mean_absolute_percentage_error(autots_actual_filtered, autots_predictions_filtered)
    #             evaluation_results[currency]['AutoTS'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
    #         else:
    #             print(f"AutoTS forecast alignment issue or no valid data for {currency}")
    #             evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'
    #     except Exception as e:
    #         print(f"Error evaluating AutoTS for {currency}: {e}")
    #         evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'


# Print the evaluation results
print("\n--- Evaluation Results ---")
print(json.dumps(evaluation_results, indent=4))
# Out:
# Evaluating models for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# Error evaluating ARIMA for AUSTRALIA - AUSTRALIAN DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for EURO AREA - EURO/US$...
# Error evaluating ARIMA for EURO AREA - EURO/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# Error evaluating ARIMA for NEW ZEALAND - NEW ZELAND DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a1eede80f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a1eede80f40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# Error evaluating ARIMA for UNITED KINGDOM - UNITED KINGDOM POUND/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# Evaluating models for BRAZIL - REAL/US$...
# Error evaluating ARIMA for BRAZIL - REAL/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for CANADA - CANADIAN DOLLAR/US$...
# Error evaluating ARIMA for CANADA - CANADIAN DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for CHINA - YUAN/US$...
# Error evaluating ARIMA for CHINA - YUAN/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for HONG KONG - HONG KONG DOLLAR/US$...
# Error evaluating ARIMA for HONG KONG - HONG KONG DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for INDIA - INDIAN RUPEE/US$...
# Error evaluating ARIMA for INDIA - INDIAN RUPEE/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for KOREA - WON/US$...
# Error evaluating ARIMA for KOREA - WON/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for MEXICO - MEXICAN PESO/US$...
# Error evaluating ARIMA for MEXICO - MEXICAN PESO/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for SOUTH AFRICA - RAND/US$...
# Error evaluating ARIMA for SOUTH AFRICA - RAND/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for SINGAPORE - SINGAPORE DOLLAR/US$...
# Error evaluating ARIMA for SINGAPORE - SINGAPORE DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for DENMARK - DANISH KRONE/US$...
# Error evaluating ARIMA for DENMARK - DANISH KRONE/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for JAPAN - YEN/US$...
# Error evaluating ARIMA for JAPAN - YEN/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for MALAYSIA - RINGGIT/US$...
# Error evaluating ARIMA for MALAYSIA - RINGGIT/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for NORWAY - NORWEGIAN KRONE/US$...
# Error evaluating ARIMA for NORWAY - NORWEGIAN KRONE/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for SWEDEN - KRONA/US$...
# Error evaluating ARIMA for SWEDEN - KRONA/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for SRI LANKA - SRI LANKAN RUPEE/US$...
# Error evaluating ARIMA for SRI LANKA - SRI LANKAN RUPEE/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for SWITZERLAND - FRANC/US$...
# Error evaluating ARIMA for SWITZERLAND - FRANC/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for TAIWAN - NEW TAIWAN DOLLAR/US$...
# Error evaluating ARIMA for TAIWAN - NEW TAIWAN DOLLAR/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Evaluating models for THAILAND - BAHT/US$...
# Error evaluating ARIMA for THAILAND - BAHT/US$: 'The `start` argument could not be matched to a location related to the index of the data.'
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# --- Evaluation Results ---
# {
#     "AUSTRALIA - AUSTRALIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.06605858939935287,
#             "RMSE": 0.0671976965067888,
#             "MAPE": 4.5168943095557506
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.013765007502692087,
#             "RMSE": 0.017274170259117046,
#             "MAPE": 0.9484185571394395
#         },
#         "LightGBM": {
#             "MAE": 0.014749361830218518,
#             "RMSE": 0.018346850239601264,
#             "MAPE": 1.0162722952351655
#         },
#         "LSTM": {
#             "MAE": 0.007915447732676674,
#             "RMSE": 0.009943261800262228,
#             "MAPE": 0.541035161890309
#         }
#     },
#     "EURO AREA - EURO/US$": {
#         "Prophet": {
#             "MAE": 0.040297489141365606,
#             "RMSE": 0.040476592005784434,
#             "MAPE": 4.46643542985669
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.006400157873971127,
#             "RMSE": 0.007649413353545354,
#             "MAPE": 0.7117967195897394
#         },
#         "LightGBM": {
#             "MAE": 0.005197541843620305,
#             "RMSE": 0.006342994397758993,
#             "MAPE": 0.5780848020133201
#         },
#         "LSTM": {
#             "MAE": 0.010395856307900483,
#             "RMSE": 0.01092508784212956,
#             "MAPE": 1.1512408518923234
#         }
#     },
#     "NEW ZEALAND - NEW ZELAND DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.07043958653064196,
#             "RMSE": 0.07424408780241652,
#             "MAPE": 4.523775796099396
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.03268192776271273,
#             "RMSE": 0.04219735605226402,
#             "MAPE": 2.1428468489261214
#         },
#         "LightGBM": {
#             "MAE": 0.029511913440165776,
#             "RMSE": 0.03933308408602494,
#             "MAPE": 1.9368085937075268
#         },
#         "LSTM": {
#             "MAE": 0.030104550257973036,
#             "RMSE": 0.03136156876144014,
#             "MAPE": 1.9452667330315077
#         }
#     },
#     "UNITED KINGDOM - UNITED KINGDOM POUND/US$": {
#         "Prophet": {
#             "MAE": 0.03505109063108847,
#             "RMSE": 0.036665644862374516,
#             "MAPE": 4.555211542140068
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.0359333220720291,
#             "RMSE": 0.03734762308947538,
#             "MAPE": 4.669261845969037
#         },
#         "LightGBM": {
#             "MAE": 0.04066390712261252,
#             "RMSE": 0.04204600292439737,
#             "MAPE": 5.282773770135026
#         },
#         "LSTM": {
#             "MAE": 0.01296168530505634,
#             "RMSE": 0.013908013245183945,
#             "MAPE": 1.68699829364857
#         }
#     },
#     "BRAZIL - REAL/US$": {
#         "Prophet": {
#             "MAE": 0.31704088613709136,
#             "RMSE": 0.32568629934150556,
#             "MAPE": 7.676781005070341
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.06726017867497033,
#             "RMSE": 0.07768518624865862,
#             "MAPE": 1.6359355528516244
#         },
#         "LightGBM": {
#             "MAE": 0.06710621184081889,
#             "RMSE": 0.07789009545629634,
#             "MAPE": 1.6304758692195542
#         },
#         "LSTM": {
#             "MAE": 0.061891719668844464,
#             "RMSE": 0.07087872977315732,
#             "MAPE": 1.5162152298571903
#         }
#     },
#     "CANADA - CANADIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.014936071973726936,
#             "RMSE": 0.01692299846173068,
#             "MAPE": 1.1305364155894286
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.009230845478602812,
#             "RMSE": 0.011234145966781673,
#             "MAPE": 0.7028587682367674
#         },
#         "LightGBM": {
#             "MAE": 0.009446713442268495,
#             "RMSE": 0.01149092455678973,
#             "MAPE": 0.7193201727194244
#         },
#         "LSTM": {
#             "MAE": 0.006982326648546294,
#             "RMSE": 0.008344120197138353,
#             "MAPE": 0.5307699072550854
#         }
#     },
#     "CHINA - YUAN/US$": {
#         "Prophet": {
#             "MAE": 0.14425259963150058,
#             "RMSE": 0.15055173287807835,
#             "MAPE": 2.0478990406862243
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.08046241923740927,
#             "RMSE": 0.0870506987932787,
#             "MAPE": 1.1462624008877385
#         },
#         "LightGBM": {
#             "MAE": 0.08143027040160646,
#             "RMSE": 0.0880067663507003,
#             "MAPE": 1.1600358054757167
#         },
#         "LSTM": {
#             "MAE": 0.01750102399743125,
#             "RMSE": 0.023138762322855014,
#             "MAPE": 0.24955862069303597
#         }
#     },
#     "HONG KONG - HONG KONG DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.02993610713014705,
#             "RMSE": 0.036676184345157334,
#             "MAPE": 0.3833273488037
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.016359676797049416,
#             "RMSE": 0.02332155034323411,
#             "MAPE": 0.209622180911828
#         },
#         "LightGBM": {
#             "MAE": 0.017926458399971503,
#             "RMSE": 0.02522962864756868,
#             "MAPE": 0.22969769781895333
#         },
#         "LSTM": {
#             "MAE": 0.007203449846350559,
#             "RMSE": 0.007768589754294819,
#             "MAPE": 0.09209006576749501
#         }
#     },
#     "INDIA - INDIAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.0389426393717167,
#             "RMSE": 1.083637839021373,
#             "MAPE": 1.4565722309466438
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.32001251220703125,
#             "RMSE": 0.38822691436715184,
#             "MAPE": 0.44829844384767875
#         },
#         "LightGBM": {
#             "MAE": 0.3568299929224035,
#             "RMSE": 0.40686115547999163,
#             "MAPE": 0.5014372555184534
#         },
#         "LSTM": {
#             "MAE": 0.48978408150050967,
#             "RMSE": 0.5737692394531028,
#             "MAPE": 0.6859553138325281
#         }
#     },
#     "KOREA - WON/US$": {
#         "Prophet": {
#             "MAE": 46.600048055726816,
#             "RMSE": 47.63207993799701,
#             "MAPE": 3.9648124447144766
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 20.072176164899556,
#             "RMSE": 22.983514805678553,
#             "MAPE": 1.720725174748795
#         },
#         "LightGBM": {
#             "MAE": 27.066063569095636,
#             "RMSE": 29.50549069712469,
#             "MAPE": 2.317519093026191
#         },
#         "LSTM": {
#             "MAE": 7.28791663128396,
#             "RMSE": 8.67416389475822,
#             "MAPE": 0.6239737817968138
#         }
#     },
#     "MEXICO - MEXICAN PESO/US$": {
#         "Prophet": {
#             "MAE": 0.7980272202861043,
#             "RMSE": 0.8357242957437641,
#             "MAPE": 4.168410109343636
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.33554600045340405,
#             "RMSE": 0.3905881920235257,
#             "MAPE": 1.758533737249721
#         },
#         "LightGBM": {
#             "MAE": 0.4539575695159129,
#             "RMSE": 0.49827626877029463,
#             "MAPE": 2.37551172439225
#         },
#         "LSTM": {
#             "MAE": 0.13362964596955668,
#             "RMSE": 0.16209009512155897,
#             "MAPE": 0.6925146483629576
#         }
#     },
#     "SOUTH AFRICA - RAND/US$": {
#         "Prophet": {
#             "MAE": 0.8202785260149034,
#             "RMSE": 0.8646040227303647,
#             "MAPE": 5.567808562487192
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.3088834119524275,
#             "RMSE": 0.39317964880546924,
#             "MAPE": 2.1393542600484206
#         },
#         "LightGBM": {
#             "MAE": 0.4031325289103228,
#             "RMSE": 0.4796829631355804,
#             "MAPE": 2.786171325943753
#         },
#         "LSTM": {
#             "MAE": 0.09832936112777048,
#             "RMSE": 0.13810494299785545,
#             "MAPE": 0.6697091718627961
#         }
#     },
#     "SINGAPORE - SINGAPORE DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.00864421121518742,
#             "RMSE": 0.010143412372086567,
#             "MAPE": 0.6336847792156813
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.0173948140825544,
#             "RMSE": 0.018323118520853693,
#             "MAPE": 1.2800260515377924
#         },
#         "LightGBM": {
#             "MAE": 0.02107276229395541,
#             "RMSE": 0.021914660696144502,
#             "MAPE": 1.550373018240965
#         },
#         "LSTM": {
#             "MAE": 0.005843393839960523,
#             "RMSE": 0.006447671384320302,
#             "MAPE": 0.4303543007177927
#         }
#     },
#     "DENMARK - DANISH KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.3127930711504582,
#             "RMSE": 0.3140828141622579,
#             "MAPE": 4.640136255303812
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.04401716515677313,
#             "RMSE": 0.053696723294012295,
#             "MAPE": 0.6553585935175951
#         },
#         "LightGBM": {
#             "MAE": 0.03428406415224605,
#             "RMSE": 0.04199151106766585,
#             "MAPE": 0.5102604081584958
#         },
#         "LSTM": {
#             "MAE": 0.03764346034837806,
#             "RMSE": 0.04460744824101529,
#             "MAPE": 0.5598913390184896
#         }
#     },
#     "JAPAN - YEN/US$": {
#         "Prophet": {
#             "MAE": 1.6185573547810412,
#             "RMSE": 1.6821193714286924,
#             "MAPE": 1.48631577299787
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 1.1706704602922708,
#             "RMSE": 1.2429953691005073,
#             "MAPE": 1.0739385135142911
#         },
#         "LightGBM": {
#             "MAE": 1.7730345274892865,
#             "RMSE": 1.8275543699737014,
#             "MAPE": 1.627211802392584
#         },
#         "LSTM": {
#             "MAE": 0.8497065535835597,
#             "RMSE": 0.9246096341766656,
#             "MAPE": 0.7790509637734594
#         }
#     },
#     "MALAYSIA - RINGGIT/US$": {
#         "Prophet": {
#             "MAE": 0.04177537290670784,
#             "RMSE": 0.04961961659762636,
#             "MAPE": 1.000936340979402
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.023530012130737337,
#             "RMSE": 0.0310161991809287,
#             "MAPE": 0.5681779604659235
#         },
#         "LightGBM": {
#             "MAE": 0.027488598745999515,
#             "RMSE": 0.035421692711285854,
#             "MAPE": 0.6636960162882304
#         },
#         "LSTM": {
#             "MAE": 0.010933172126438325,
#             "RMSE": 0.01441887341276019,
#             "MAPE": 0.263807572325546
#         }
#     },
#     "NORWAY - NORWEGIAN KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.6433390095412392,
#             "RMSE": 0.6580763279512826,
#             "MAPE": 7.048840870247002
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.12273484551565993,
#             "RMSE": 0.13327437238810053,
#             "MAPE": 1.3474026467374585
#         },
#         "LightGBM": {
#             "MAE": 0.12046156309099729,
#             "RMSE": 0.1310204419353087,
#             "MAPE": 1.3227721723515555
#         },
#         "LSTM": {
#             "MAE": 0.041721704930844684,
#             "RMSE": 0.04878765397808237,
#             "MAPE": 0.4585620486594859
#         }
#     },
#     "SWEDEN - KRONA/US$": {
#         "Prophet": {
#             "MAE": 0.3339634810528948,
#             "RMSE": 0.3687304478178595,
#             "MAPE": 3.4614607795596766
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.17806895909990592,
#             "RMSE": 0.2140522867301518,
#             "MAPE": 1.8743294579729657
#         },
#         "LightGBM": {
#             "MAE": 0.16438357150193675,
#             "RMSE": 0.20180938270021723,
#             "MAPE": 1.730711591270858
#         },
#         "LSTM": {
#             "MAE": 0.0413281192281972,
#             "RMSE": 0.04980466921079855,
#             "MAPE": 0.4337535846134171
#         }
#     },
#     "SRI LANKA - SRI LANKAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.6458978050512125,
#             "RMSE": 1.981339299442387,
#             "MAPE": 0.9084761789035547
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.48385931832449863,
#             "RMSE": 0.6349596633173797,
#             "MAPE": 0.2678700603060605
#         },
#         "LightGBM": {
#             "MAE": 0.8254695016133345,
#             "RMSE": 0.927207485935046,
#             "MAPE": 0.4556843518204043
#         },
#         "LSTM": {
#             "MAE": 1.8653586213485038,
#             "RMSE": 1.9436074877529361,
#             "MAPE": 1.0307987224048587
#         }
#     },
#     "SWITZERLAND - FRANC/US$": {
#         "Prophet": {
#             "MAE": 0.006368680397253272,
#             "RMSE": 0.007321715990603664,
#             "MAPE": 0.6457918895715425
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.005869119790622169,
#             "RMSE": 0.007856604467193388,
#             "MAPE": 0.5966691175034229
#         },
#         "LightGBM": {
#             "MAE": 0.0055343234770226036,
#             "RMSE": 0.007074247276622502,
#             "MAPE": 0.5603166779404074
#         },
#         "LSTM": {
#             "MAE": 0.01079639243042988,
#             "RMSE": 0.011742058040162125,
#             "MAPE": 1.0955166429513237
#         }
#     },
#     "TAIWAN - NEW TAIWAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.3026421947257079,
#             "RMSE": 0.34220320452423275,
#             "MAPE": 0.9914399338560481
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.5881658063616071,
#             "RMSE": 0.6192858825239017,
#             "MAPE": 1.9370593932017566
#         },
#         "LightGBM": {
#             "MAE": 0.7253689348008996,
#             "RMSE": 0.7508236011837933,
#             "MAPE": 2.3879721304703754
#         },
#         "LSTM": {
#             "MAE": 0.14820094564686778,
#             "RMSE": 0.16271330598946074,
#             "MAPE": 0.48860427786772564
#         }
#     },
#     "THAILAND - BAHT/US$": {
#         "Prophet": {
#             "MAE": 0.5398518631960332,
#             "RMSE": 0.5539210055784246,
#             "MAPE": 1.7859244707269732
#         },
#         "ARIMA": "Evaluation Failed",
#         "XGBoost": {
#             "MAE": 0.32923381260463164,
#             "RMSE": 0.34563606744274206,
#             "MAPE": 1.0900963310884224
#         },
#         "LightGBM": {
#             "MAE": 0.37006638624678406,
#             "RMSE": 0.38473174808541083,
#             "MAPE": 1.2251422774094565
#         },
#         "LSTM": {
#             "MAE": 0.1518743680871053,
#             "RMSE": 0.16581293027309435,
#             "MAPE": 0.5022519072004796
#         }
#     }
# }

# %% [markdown]
# **Reasoning**:
# The previous command failed to evaluate the ARIMA model due to an index mismatch. I need to fix the ARIMA evaluation part of the code to correctly align the ARIMA forecast with the test data based on dates. The LightGBM evaluation also produced warnings about feature names, which can be addressed by providing feature names or disabling the warning if appropriate, but the primary failure is with ARIMA.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import json
import pandas as pd

# Function to calculate Mean Absolute Percentage Error
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates the Mean Absolute Percentage Error."""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero by replacing 0 with a small epsilon or handling
    # cases where y_true is zero.
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

# Re-initialize evaluation_results to clear previous partial results
evaluation_results = {}

# Iterate through each currency in currency_data
for currency, (train_data, test_data) in currency_data.items():
    print(f"Evaluating models for {currency}...")
    evaluation_results[currency] = {}

    # Extract actual values for the test period, dropping NaNs for evaluation consistency
    # across models that handle NaNs differently.
    test_data_cleaned = test_data.copy().dropna()
    actual_values = test_data_cleaned[currency].values
    test_dates = test_data_cleaned['Time Serie']

    # Prophet Evaluation
    if currency in prophet_models:
        try:
            model = prophet_models[currency]
            # Prophet requires a future dataframe with 'ds' column for forecasting
            future = pd.DataFrame({'ds': test_dates})
            forecast = model.predict(future)

            # Align the forecast with the cleaned test data's dates
            prophet_forecast = forecast.set_index('ds').reindex(test_dates)['yhat'].values

            if len(actual_values) > 0 and len(prophet_forecast) == len(actual_values):
                mae = mean_absolute_error(actual_values, prophet_forecast)
                rmse = np.sqrt(mean_squared_error(actual_values, prophet_forecast))
                mape = mean_absolute_percentage_error(actual_values, prophet_forecast)
                evaluation_results[currency]['Prophet'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Prophet forecast alignment issue or no valid data for {currency}")
                 evaluation_results[currency]['Prophet'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating Prophet for {currency}: {e}")
            evaluation_results[currency]['Prophet'] = 'Evaluation Failed'


    # ARIMA Evaluation
    if currency in arima_models:
        try:
            model_fit = arima_models[currency]
            # Forecast for the dates in the cleaned test data
            # ARIMA's forecast method can take start and end dates or steps
            # Using the index of the test data to forecast should align it correctly
            if not test_data_cleaned.empty:
                # Get the index of the test data that ARIMA was trained on (which is based on Time Serie)
                # This assumes the ARIMA model's index corresponds to the training data's Time Serie index
                # However, ARIMA fit ignores the date index if frequency is not set.
                # A more robust way is to use the forecast method with steps equal to test data length
                # and then align based on the 'Time Serie' column of test_data_cleaned.

                # The ARIMA model was trained on data with a date index, but the warning indicated
                # the frequency was ignored. Let's try forecasting by steps and then aligning.
                # Get the index of the start of the test period in the *original* data
                start_idx = train_data.index[-1] + 1 # Index after the last training data point
                end_idx = start_idx + len(test_data_cleaned) - 1 # Index corresponding to the last test data point

                # Forecast using steps, starting from the end of the training data
                # Need to handle the case where ARIMA training data was shorter due to NaNs
                # A simpler approach might be to predict the *next* len(test_data_cleaned) steps
                # directly from the fitted model.

                # Let's reconsider. The ARIMA model was fit on a Series with DateTimeIndex.
                # The forecast method should ideally work with dates from that index's frequency.
                # The error "start argument could not be matched" suggests the test_dates were
                # not in the expected format or range relative to the training index.
                # If the training data index is consecutive integers (due to ignoring freq),
                # forecasting by steps is the correct approach. If it's DateTimeIndex,
                # passing the actual test dates should work if their frequency is consistent.

                # Based on the training code, arima_train_data has Time Serie as index.
                # Let's try forecasting by steps relative to the length of the training data.
                # The forecast should start immediately after the training data ends.
                n_forecast_steps = len(test_data_cleaned)
                # Ensure there is enough data to make forecasts
                if len(model_fit.fittedvalues) + n_forecast_steps <= len(train_data[currency].dropna()):
                     arima_forecast = model_fit.forecast(steps=n_forecast_steps)

                     # Align ARIMA forecast with the actual values based on date index
                     # Create a pandas Series for the forecast with the test_dates as index
                     # This assumes the forecast order corresponds to the order of test_dates
                     arima_forecast_series = pd.Series(arima_forecast.values, index=test_dates)

                     # Reindex the forecast to match the test_data_cleaned index (just in case)
                     arima_forecast_aligned = arima_forecast_series.reindex(test_dates).values

                     # Use the cleaned actual values directly
                     arima_actual_filtered = actual_values
                     arima_forecast_filtered = arima_forecast_aligned

                     # Drop any remaining NaNs that might have occurred during reindexing
                     valid_indices = ~np.isnan(arima_actual_filtered) & ~np.isnan(arima_forecast_filtered)
                     arima_actual_filtered = arima_actual_filtered[valid_indices]
                     arima_forecast_filtered = arima_forecast_filtered[valid_indices]


                     if len(arima_actual_filtered) > 0 and len(arima_forecast_filtered) == len(arima_actual_filtered):
                         mae = mean_absolute_error(arima_actual_filtered, arima_forecast_filtered)
                         rmse = np.sqrt(mean_squared_error(arima_actual_filtered, arima_forecast_filtered))
                         mape = mean_absolute_percentage_error(arima_actual_filtered, arima_forecast_filtered)
                         evaluation_results[currency]['ARIMA'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
                     else:
                          print(f"ARIMA forecast alignment issue or no valid data for {currency}")
                          evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'
                else:
                     print(f"Not enough data in training set relative to test set length for ARIMA forecasting for {currency}")
                     evaluation_results[currency]['ARIMA'] = 'Evaluation Failed - Insufficient Data'


            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for ARIMA evaluation.")
                 evaluation_results[currency]['ARIMA'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating ARIMA for {currency}: {e}")
            evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'

    # XGBoost Evaluation
    if currency in xgboost_models:
        try:
            model = xgboost_models[currency]
            # Prepare test data for XGBoost (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                xgboost_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, xgboost_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, xgboost_predictions))
                mape = mean_absolute_percentage_error(y_test, xgboost_predictions)
                evaluation_results[currency]['XGBoost'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for XGBoost evaluation.")
                 evaluation_results[currency]['XGBoost'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating XGBoost for {currency}: {e}")
            evaluation_results[currency]['XGBoost'] = 'Evaluation Failed'

    # LightGBM Evaluation
    if currency in lightgbm_models:
        try:
            model = lightgbm_models[currency]
            # Prepare test data for LightGBM (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                # Suppress the specific UserWarning about feature names if it's not a functional issue
                import warnings
                with warnings.catch_warnings():
                    warnings.filterwarnings("ignore", message="X does not have valid feature names, but LGBMRegressor was fitted with feature names")
                    lightgbm_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, lightgbm_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, lightgbm_predictions))
                mape = mean_absolute_percentage_error(y_test, lightgbm_predictions)
                evaluation_results[currency]['LightGBM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for LightGBM evaluation.")
                 evaluation_results[currency]['LightGBM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LightGBM for {currency}: {e}")
            evaluation_results[currency]['LightGBM'] = 'Evaluation Failed'

    # LSTM Evaluation
    if currency in lstm_models and currency in lstm_scalers:
        try:
            model = lstm_models[currency]
            scaler = lstm_scalers[currency]

            # Prepare test data for LSTM (using cleaned data)
            # LSTM needs sequential data, so we need to process the cleaned test data
            lstm_test_data_values = test_data_cleaned[currency].values.reshape(-1, 1)

            if len(lstm_test_data_values) >= seq_length:
                 scaled_test_data = scaler.transform(lstm_test_data_values)

                 # Create sequences for the test data
                 # Note: create_sequences expects a numpy array
                 X_test, y_test_scaled = create_sequences(scaled_test_data, seq_length)
                 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

                 # Ensure predictions are made for the correct number of samples
                 if X_test.shape[0] > 0:
                     lstm_predictions_scaled = model.predict(X_test, verbose=0) # Reduce verbosity
                     lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
                     y_test = scaler.inverse_transform(y_test_scaled.reshape(-1, 1)) # Inverse transform actuals

                     mae = mean_absolute_error(y_test, lstm_predictions)
                     rmse = np.sqrt(mean_squared_error(y_test, lstm_predictions))
                     mape = mean_absolute_percentage_error(y_test, lstm_predictions)
                     evaluation_results[currency]['LSTM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
                 else:
                     print(f"LSTM test sequence creation resulted in no samples for {currency}")
                     evaluation_results[currency]['LSTM'] = 'Evaluation Failed - No Test Samples'


            else:
                 print(f"Test data for {currency} is too short for LSTM evaluation (requires at least {seq_length} data points after dropping NaNs).")
                 evaluation_results[currency]['LSTM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LSTM for {currency}: {e}")
            evaluation_results[currency]['LSTM'] = 'Evaluation Failed'

    # AutoTS Evaluation (Placeholder - needs implementation based on AutoTS forecasting)
    # If AutoTS was trained and forecasts were generated, evaluate here.
    # Example: if 'autots_forecasts' dictionary exists with currency as key
    # if currency in autots_forecasts:
    #     try:
    #         autots_predictions = autots_forecasts[currency] # Needs to be defined
    #         # Align AutoTS forecasts with cleaned test data
    #         # This depends on how AutoTS forecasts are generated and indexed
    #         # Assuming autots_forecasts is a Series or DataFrame with a datetime index
    #         autots_predictions_aligned = autots_predictions.reindex(test_dates).dropna().values
    #         autots_actual_filtered = actual_values[~np.isnan(autots_predictions_aligned)]
    #         autots_predictions_filtered = autots_predictions_aligned[~np.isnan(autots_predictions_aligned)]

    #         if len(autots_actual_filtered) > 0 and len(autots_predictions_filtered) == len(autots_actual_filtered):
    #             mae = mean_absolute_error(autots_actual_filtered, autots_predictions_filtered)
    #             rmse = np.sqrt(mean_squared_error(autots_actual_filtered, autots_predictions_filtered))
    #             mape = mean_absolute_percentage_error(autots_actual_filtered, autots_predictions_filtered)
    #             evaluation_results[currency]['AutoTS'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
    #         else:
    #             print(f"AutoTS forecast alignment issue or no valid data for {currency}")
    #             evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'
    #     except Exception as e:
    #         print(f"Error evaluating AutoTS for {currency}: {e}")
    #         evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'


# Print the evaluation results
print("\n--- Evaluation Results ---")
print(json.dumps(evaluation_results, indent=4))
# Out:
# Evaluating models for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for AUSTRALIA - AUSTRALIAN DOLLAR/US$
# Evaluating models for EURO AREA - EURO/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for EURO AREA - EURO/US$
# Evaluating models for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for NEW ZEALAND - NEW ZELAND DOLLAR/US$
# Evaluating models for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for UNITED KINGDOM - UNITED KINGDOM POUND/US$
# Evaluating models for BRAZIL - REAL/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for BRAZIL - REAL/US$
# Evaluating models for CANADA - CANADIAN DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for CANADA - CANADIAN DOLLAR/US$
# Evaluating models for CHINA - YUAN/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for CHINA - YUAN/US$
# Evaluating models for HONG KONG - HONG KONG DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for HONG KONG - HONG KONG DOLLAR/US$
# Evaluating models for INDIA - INDIAN RUPEE/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for INDIA - INDIAN RUPEE/US$
# Evaluating models for KOREA - WON/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for KOREA - WON/US$
# Evaluating models for MEXICO - MEXICAN PESO/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for MEXICO - MEXICAN PESO/US$
# Evaluating models for SOUTH AFRICA - RAND/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for SOUTH AFRICA - RAND/US$
# Evaluating models for SINGAPORE - SINGAPORE DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for SINGAPORE - SINGAPORE DOLLAR/US$
# Evaluating models for DENMARK - DANISH KRONE/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for DENMARK - DANISH KRONE/US$
# Evaluating models for JAPAN - YEN/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for JAPAN - YEN/US$
# Evaluating models for MALAYSIA - RINGGIT/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for MALAYSIA - RINGGIT/US$
# Evaluating models for NORWAY - NORWEGIAN KRONE/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for NORWAY - NORWEGIAN KRONE/US$
# Evaluating models for SWEDEN - KRONA/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for SWEDEN - KRONA/US$
# Evaluating models for SRI LANKA - SRI LANKAN RUPEE/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for SRI LANKA - SRI LANKAN RUPEE/US$
# Evaluating models for SWITZERLAND - FRANC/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for SWITZERLAND - FRANC/US$
# Evaluating models for TAIWAN - NEW TAIWAN DOLLAR/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for TAIWAN - NEW TAIWAN DOLLAR/US$
# Evaluating models for THAILAND - BAHT/US$...
# Not enough data in training set relative to test set length for ARIMA forecasting for THAILAND - BAHT/US$
#
# --- Evaluation Results ---
# {
#     "AUSTRALIA - AUSTRALIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.06605858939935287,
#             "RMSE": 0.0671976965067888,
#             "MAPE": 4.5168943095557506
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.013765007502692087,
#             "RMSE": 0.017274170259117046,
#             "MAPE": 0.9484185571394395
#         },
#         "LightGBM": {
#             "MAE": 0.014749361830218518,
#             "RMSE": 0.018346850239601264,
#             "MAPE": 1.0162722952351655
#         },
#         "LSTM": {
#             "MAE": 0.007915447732676674,
#             "RMSE": 0.009943261800262228,
#             "MAPE": 0.541035161890309
#         }
#     },
#     "EURO AREA - EURO/US$": {
#         "Prophet": {
#             "MAE": 0.040297489141365606,
#             "RMSE": 0.040476592005784434,
#             "MAPE": 4.46643542985669
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.006400157873971127,
#             "RMSE": 0.007649413353545354,
#             "MAPE": 0.7117967195897394
#         },
#         "LightGBM": {
#             "MAE": 0.005197541843620305,
#             "RMSE": 0.006342994397758993,
#             "MAPE": 0.5780848020133201
#         },
#         "LSTM": {
#             "MAE": 0.010395856307900483,
#             "RMSE": 0.01092508784212956,
#             "MAPE": 1.1512408518923234
#         }
#     },
#     "NEW ZEALAND - NEW ZELAND DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.07043958653064196,
#             "RMSE": 0.07424408780241652,
#             "MAPE": 4.523775796099396
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.03268192776271273,
#             "RMSE": 0.04219735605226402,
#             "MAPE": 2.1428468489261214
#         },
#         "LightGBM": {
#             "MAE": 0.029511913440165776,
#             "RMSE": 0.03933308408602494,
#             "MAPE": 1.9368085937075268
#         },
#         "LSTM": {
#             "MAE": 0.030104550257973036,
#             "RMSE": 0.03136156876144014,
#             "MAPE": 1.9452667330315077
#         }
#     },
#     "UNITED KINGDOM - UNITED KINGDOM POUND/US$": {
#         "Prophet": {
#             "MAE": 0.03505109063108847,
#             "RMSE": 0.036665644862374516,
#             "MAPE": 4.555211542140068
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.0359333220720291,
#             "RMSE": 0.03734762308947538,
#             "MAPE": 4.669261845969037
#         },
#         "LightGBM": {
#             "MAE": 0.04066390712261252,
#             "RMSE": 0.04204600292439737,
#             "MAPE": 5.282773770135026
#         },
#         "LSTM": {
#             "MAE": 0.01296168530505634,
#             "RMSE": 0.013908013245183945,
#             "MAPE": 1.68699829364857
#         }
#     },
#     "BRAZIL - REAL/US$": {
#         "Prophet": {
#             "MAE": 0.31704088613709136,
#             "RMSE": 0.32568629934150556,
#             "MAPE": 7.676781005070341
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.06726017867497033,
#             "RMSE": 0.07768518624865862,
#             "MAPE": 1.6359355528516244
#         },
#         "LightGBM": {
#             "MAE": 0.06710621184081889,
#             "RMSE": 0.07789009545629634,
#             "MAPE": 1.6304758692195542
#         },
#         "LSTM": {
#             "MAE": 0.061891719668844464,
#             "RMSE": 0.07087872977315732,
#             "MAPE": 1.5162152298571903
#         }
#     },
#     "CANADA - CANADIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.014936071973726936,
#             "RMSE": 0.01692299846173068,
#             "MAPE": 1.1305364155894286
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.009230845478602812,
#             "RMSE": 0.011234145966781673,
#             "MAPE": 0.7028587682367674
#         },
#         "LightGBM": {
#             "MAE": 0.009446713442268495,
#             "RMSE": 0.01149092455678973,
#             "MAPE": 0.7193201727194244
#         },
#         "LSTM": {
#             "MAE": 0.006982326648546294,
#             "RMSE": 0.008344120197138353,
#             "MAPE": 0.5307699072550854
#         }
#     },
#     "CHINA - YUAN/US$": {
#         "Prophet": {
#             "MAE": 0.14425259963150058,
#             "RMSE": 0.15055173287807835,
#             "MAPE": 2.0478990406862243
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.08046241923740927,
#             "RMSE": 0.0870506987932787,
#             "MAPE": 1.1462624008877385
#         },
#         "LightGBM": {
#             "MAE": 0.08143027040160646,
#             "RMSE": 0.0880067663507003,
#             "MAPE": 1.1600358054757167
#         },
#         "LSTM": {
#             "MAE": 0.01750102399743125,
#             "RMSE": 0.023138762322855014,
#             "MAPE": 0.24955862069303597
#         }
#     },
#     "HONG KONG - HONG KONG DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.02993610713014705,
#             "RMSE": 0.036676184345157334,
#             "MAPE": 0.3833273488037
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.016359676797049416,
#             "RMSE": 0.02332155034323411,
#             "MAPE": 0.209622180911828
#         },
#         "LightGBM": {
#             "MAE": 0.017926458399971503,
#             "RMSE": 0.02522962864756868,
#             "MAPE": 0.22969769781895333
#         },
#         "LSTM": {
#             "MAE": 0.007203449846350559,
#             "RMSE": 0.007768589754294819,
#             "MAPE": 0.09209006576749501
#         }
#     },
#     "INDIA - INDIAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.0389426393717167,
#             "RMSE": 1.083637839021373,
#             "MAPE": 1.4565722309466438
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.32001251220703125,
#             "RMSE": 0.38822691436715184,
#             "MAPE": 0.44829844384767875
#         },
#         "LightGBM": {
#             "MAE": 0.3568299929224035,
#             "RMSE": 0.40686115547999163,
#             "MAPE": 0.5014372555184534
#         },
#         "LSTM": {
#             "MAE": 0.48978408150050967,
#             "RMSE": 0.5737692394531028,
#             "MAPE": 0.6859553138325281
#         }
#     },
#     "KOREA - WON/US$": {
#         "Prophet": {
#             "MAE": 46.600048055726816,
#             "RMSE": 47.63207993799701,
#             "MAPE": 3.9648124447144766
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 20.072176164899556,
#             "RMSE": 22.983514805678553,
#             "MAPE": 1.720725174748795
#         },
#         "LightGBM": {
#             "MAE": 27.066063569095636,
#             "RMSE": 29.50549069712469,
#             "MAPE": 2.317519093026191
#         },
#         "LSTM": {
#             "MAE": 7.28791663128396,
#             "RMSE": 8.67416389475822,
#             "MAPE": 0.6239737817968138
#         }
#     },
#     "MEXICO - MEXICAN PESO/US$": {
#         "Prophet": {
#             "MAE": 0.7980272202861043,
#             "RMSE": 0.8357242957437641,
#             "MAPE": 4.168410109343636
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.33554600045340405,
#             "RMSE": 0.3905881920235257,
#             "MAPE": 1.758533737249721
#         },
#         "LightGBM": {
#             "MAE": 0.4539575695159129,
#             "RMSE": 0.49827626877029463,
#             "MAPE": 2.37551172439225
#         },
#         "LSTM": {
#             "MAE": 0.13362964596955668,
#             "RMSE": 0.16209009512155897,
#             "MAPE": 0.6925146483629576
#         }
#     },
#     "SOUTH AFRICA - RAND/US$": {
#         "Prophet": {
#             "MAE": 0.8202785260149034,
#             "RMSE": 0.8646040227303647,
#             "MAPE": 5.567808562487192
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.3088834119524275,
#             "RMSE": 0.39317964880546924,
#             "MAPE": 2.1393542600484206
#         },
#         "LightGBM": {
#             "MAE": 0.4031325289103228,
#             "RMSE": 0.4796829631355804,
#             "MAPE": 2.786171325943753
#         },
#         "LSTM": {
#             "MAE": 0.09832936112777048,
#             "RMSE": 0.13810494299785545,
#             "MAPE": 0.6697091718627961
#         }
#     },
#     "SINGAPORE - SINGAPORE DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.00864421121518742,
#             "RMSE": 0.010143412372086567,
#             "MAPE": 0.6336847792156813
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.0173948140825544,
#             "RMSE": 0.018323118520853693,
#             "MAPE": 1.2800260515377924
#         },
#         "LightGBM": {
#             "MAE": 0.02107276229395541,
#             "RMSE": 0.021914660696144502,
#             "MAPE": 1.550373018240965
#         },
#         "LSTM": {
#             "MAE": 0.005843393839960523,
#             "RMSE": 0.006447671384320302,
#             "MAPE": 0.4303543007177927
#         }
#     },
#     "DENMARK - DANISH KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.3127930711504582,
#             "RMSE": 0.3140828141622579,
#             "MAPE": 4.640136255303812
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.04401716515677313,
#             "RMSE": 0.053696723294012295,
#             "MAPE": 0.6553585935175951
#         },
#         "LightGBM": {
#             "MAE": 0.03428406415224605,
#             "RMSE": 0.04199151106766585,
#             "MAPE": 0.5102604081584958
#         },
#         "LSTM": {
#             "MAE": 0.03764346034837806,
#             "RMSE": 0.04460744824101529,
#             "MAPE": 0.5598913390184896
#         }
#     },
#     "JAPAN - YEN/US$": {
#         "Prophet": {
#             "MAE": 1.6185573547810412,
#             "RMSE": 1.6821193714286924,
#             "MAPE": 1.48631577299787
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 1.1706704602922708,
#             "RMSE": 1.2429953691005073,
#             "MAPE": 1.0739385135142911
#         },
#         "LightGBM": {
#             "MAE": 1.7730345274892865,
#             "RMSE": 1.8275543699737014,
#             "MAPE": 1.627211802392584
#         },
#         "LSTM": {
#             "MAE": 0.8497065535835597,
#             "RMSE": 0.9246096341766656,
#             "MAPE": 0.7790509637734594
#         }
#     },
#     "MALAYSIA - RINGGIT/US$": {
#         "Prophet": {
#             "MAE": 0.04177537290670784,
#             "RMSE": 0.04961961659762636,
#             "MAPE": 1.000936340979402
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.023530012130737337,
#             "RMSE": 0.0310161991809287,
#             "MAPE": 0.5681779604659235
#         },
#         "LightGBM": {
#             "MAE": 0.027488598745999515,
#             "RMSE": 0.035421692711285854,
#             "MAPE": 0.6636960162882304
#         },
#         "LSTM": {
#             "MAE": 0.010933172126438325,
#             "RMSE": 0.01441887341276019,
#             "MAPE": 0.263807572325546
#         }
#     },
#     "NORWAY - NORWEGIAN KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.6433390095412392,
#             "RMSE": 0.6580763279512826,
#             "MAPE": 7.048840870247002
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.12273484551565993,
#             "RMSE": 0.13327437238810053,
#             "MAPE": 1.3474026467374585
#         },
#         "LightGBM": {
#             "MAE": 0.12046156309099729,
#             "RMSE": 0.1310204419353087,
#             "MAPE": 1.3227721723515555
#         },
#         "LSTM": {
#             "MAE": 0.041721704930844684,
#             "RMSE": 0.04878765397808237,
#             "MAPE": 0.4585620486594859
#         }
#     },
#     "SWEDEN - KRONA/US$": {
#         "Prophet": {
#             "MAE": 0.3339634810528948,
#             "RMSE": 0.3687304478178595,
#             "MAPE": 3.4614607795596766
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.17806895909990592,
#             "RMSE": 0.2140522867301518,
#             "MAPE": 1.8743294579729657
#         },
#         "LightGBM": {
#             "MAE": 0.16438357150193675,
#             "RMSE": 0.20180938270021723,
#             "MAPE": 1.730711591270858
#         },
#         "LSTM": {
#             "MAE": 0.0413281192281972,
#             "RMSE": 0.04980466921079855,
#             "MAPE": 0.4337535846134171
#         }
#     },
#     "SRI LANKA - SRI LANKAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.6458978050512125,
#             "RMSE": 1.981339299442387,
#             "MAPE": 0.9084761789035547
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.48385931832449863,
#             "RMSE": 0.6349596633173797,
#             "MAPE": 0.2678700603060605
#         },
#         "LightGBM": {
#             "MAE": 0.8254695016133345,
#             "RMSE": 0.927207485935046,
#             "MAPE": 0.4556843518204043
#         },
#         "LSTM": {
#             "MAE": 1.8653586213485038,
#             "RMSE": 1.9436074877529361,
#             "MAPE": 1.0307987224048587
#         }
#     },
#     "SWITZERLAND - FRANC/US$": {
#         "Prophet": {
#             "MAE": 0.006368680397253272,
#             "RMSE": 0.007321715990603664,
#             "MAPE": 0.6457918895715425
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.005869119790622169,
#             "RMSE": 0.007856604467193388,
#             "MAPE": 0.5966691175034229
#         },
#         "LightGBM": {
#             "MAE": 0.0055343234770226036,
#             "RMSE": 0.007074247276622502,
#             "MAPE": 0.5603166779404074
#         },
#         "LSTM": {
#             "MAE": 0.01079639243042988,
#             "RMSE": 0.011742058040162125,
#             "MAPE": 1.0955166429513237
#         }
#     },
#     "TAIWAN - NEW TAIWAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.3026421947257079,
#             "RMSE": 0.34220320452423275,
#             "MAPE": 0.9914399338560481
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.5881658063616071,
#             "RMSE": 0.6192858825239017,
#             "MAPE": 1.9370593932017566
#         },
#         "LightGBM": {
#             "MAE": 0.7253689348008996,
#             "RMSE": 0.7508236011837933,
#             "MAPE": 2.3879721304703754
#         },
#         "LSTM": {
#             "MAE": 0.14820094564686778,
#             "RMSE": 0.16271330598946074,
#             "MAPE": 0.48860427786772564
#         }
#     },
#     "THAILAND - BAHT/US$": {
#         "Prophet": {
#             "MAE": 0.5398518631960332,
#             "RMSE": 0.5539210055784246,
#             "MAPE": 1.7859244707269732
#         },
#         "ARIMA": "Evaluation Failed - Insufficient Data",
#         "XGBoost": {
#             "MAE": 0.32923381260463164,
#             "RMSE": 0.34563606744274206,
#             "MAPE": 1.0900963310884224
#         },
#         "LightGBM": {
#             "MAE": 0.37006638624678406,
#             "RMSE": 0.38473174808541083,
#             "MAPE": 1.2251422774094565
#         },
#         "LSTM": {
#             "MAE": 0.1518743680871053,
#             "RMSE": 0.16581293027309435,
#             "MAPE": 0.5022519072004796
#         }
#     }
# }

# %% [markdown]
# **Reasoning**:
# The ARIMA evaluation is still failing because the forecast length logic is incorrect when dealing with dropped NaNs in the test set. I need to adjust how the number of steps for the ARIMA forecast is determined to match the length of the *cleaned* test data.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import json
import pandas as pd
import warnings

# Function to calculate Mean Absolute Percentage Error
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates the Mean Absolute Percentage Error."""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # Avoid division by zero by replacing 0 with a small epsilon or handling
    # cases where y_true is zero.
    return np.mean(np.abs((y_true - y_pred) / (y_true + 1e-8))) * 100

# Re-initialize evaluation_results to clear previous partial results
evaluation_results = {}

# Iterate through each currency in currency_data
for currency, (train_data, test_data) in currency_data.items():
    print(f"Evaluating models for {currency}...")
    evaluation_results[currency] = {}

    # Extract actual values for the test period, dropping NaNs for evaluation consistency
    # across models that handle NaNs differently.
    test_data_cleaned = test_data.copy().dropna()
    actual_values = test_data_cleaned[currency].values
    test_dates = test_data_cleaned['Time Serie']

    # Prophet Evaluation
    if currency in prophet_models:
        try:
            model = prophet_models[currency]
            # Prophet requires a future dataframe with 'ds' column for forecasting
            future = pd.DataFrame({'ds': test_dates})
            forecast = model.predict(future)

            # Align the forecast with the cleaned test data's dates
            prophet_forecast = forecast.set_index('ds').reindex(test_dates)['yhat'].values

            if len(actual_values) > 0 and len(prophet_forecast) == len(actual_values):
                mae = mean_absolute_error(actual_values, prophet_forecast)
                rmse = np.sqrt(mean_squared_error(actual_values, prophet_forecast))
                mape = mean_absolute_percentage_error(actual_values, prophet_forecast)
                evaluation_results[currency]['Prophet'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Prophet forecast alignment issue or no valid data for {currency}")
                 evaluation_results[currency]['Prophet'] = 'Evaluation Failed'

        except Exception as e:
            print(f"Error evaluating Prophet for {currency}: {e}")
            evaluation_results[currency]['Prophet'] = 'Evaluation Failed'


    # ARIMA Evaluation
    if currency in arima_models:
        try:
            model_fit = arima_models[currency]
            # Forecast for the length of the cleaned test data
            n_forecast_steps = len(test_data_cleaned)

            if n_forecast_steps > 0:
                # Forecast the next n_forecast_steps steps
                arima_forecast = model_fit.forecast(steps=n_forecast_steps)

                # Align ARIMA forecast with the actual values based on the order of cleaned test data
                # Since we are forecasting a fixed number of steps, and test_data_cleaned is ordered by date,
                # we assume the forecast corresponds directly to the actual values.
                arima_actual_filtered = actual_values
                arima_forecast_filtered = arima_forecast.values # Get values from the forecast Series

                if len(arima_actual_filtered) > 0 and len(arima_forecast_filtered) == len(arima_actual_filtered):
                    mae = mean_absolute_error(arima_actual_filtered, arima_forecast_filtered)
                    rmse = np.sqrt(mean_squared_error(arima_actual_filtered, arima_forecast_filtered))
                    mape = mean_absolute_percentage_error(arima_actual_filtered, arima_forecast_filtered)
                    evaluation_results[currency]['ARIMA'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
                else:
                     print(f"ARIMA forecast length mismatch with cleaned test data for {currency}")
                     evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for ARIMA evaluation.")
                 evaluation_results[currency]['ARIMA'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating ARIMA for {currency}: {e}")
            evaluation_results[currency]['ARIMA'] = 'Evaluation Failed'

    # XGBoost Evaluation
    if currency in xgboost_models:
        try:
            model = xgboost_models[currency]
            # Prepare test data for XGBoost (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                xgboost_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, xgboost_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, xgboost_predictions))
                mape = mean_absolute_percentage_error(y_test, xgboost_predictions)
                evaluation_results[currency]['XGBoost'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for XGBoost evaluation.")
                 evaluation_results[currency]['XGBoost'] = 'Evaluation Failed - Insufficient Data'


        except Exception as e:
            print(f"Error evaluating XGBoost for {currency}: {e}")
            evaluation_results[currency]['XGBoost'] = 'Evaluation Failed'

    # LightGBM Evaluation
    if currency in lightgbm_models:
        try:
            model = lightgbm_models[currency]
            # Prepare test data for LightGBM (using cleaned data)
            if not test_data_cleaned.empty:
                X_test = test_data_cleaned['Time Serie'].apply(lambda x: x.timestamp()).values.reshape(-1, 1)
                y_test = actual_values # Use actual_values from cleaned data

                # Suppress the specific UserWarning about feature names if it's not a functional issue
                with warnings.catch_warnings():
                    warnings.filterwarnings("ignore", message="X does not have valid feature names, but LGBMRegressor was fitted with feature names")
                    lightgbm_predictions = model.predict(X_test)

                mae = mean_absolute_error(y_test, lightgbm_predictions)
                rmse = np.sqrt(mean_squared_error(y_test, lightgbm_predictions))
                mape = mean_absolute_percentage_error(y_test, lightgbm_predictions)
                evaluation_results[currency]['LightGBM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
            else:
                 print(f"Test data for {currency} is empty after dropping NaNs for LightGBM evaluation.")
                 evaluation_results[currency]['LightGBM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LightGBM for {currency}: {e}")
            evaluation_results[currency]['LightGBM'] = 'Evaluation Failed'

    # LSTM Evaluation
    if currency in lstm_models and currency in lstm_scalers:
        try:
            model = lstm_models[currency]
            scaler = lstm_scalers[currency]

            # Prepare test data for LSTM (using cleaned data)
            # LSTM needs sequential data, so we need to process the cleaned test data
            lstm_test_data_values = test_data_cleaned[currency].values.reshape(-1, 1)

            if len(lstm_test_data_values) >= seq_length:
                 scaled_test_data = scaler.transform(lstm_test_data_values)

                 # Create sequences for the test data
                 # Note: create_sequences expects a numpy array
                 X_test, y_test_scaled = create_sequences(scaled_test_data, seq_length)
                 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

                 # Ensure predictions are made for the correct number of samples
                 if X_test.shape[0] > 0:
                     lstm_predictions_scaled = model.predict(X_test, verbose=0) # Reduce verbosity
                     lstm_predictions = scaler.inverse_transform(lstm_predictions_scaled)
                     y_test = scaler.inverse_transform(y_test_scaled.reshape(-1, 1)) # Inverse transform actuals

                     mae = mean_absolute_error(y_test, lstm_predictions)
                     rmse = np.sqrt(mean_squared_error(y_test, lstm_predictions))
                     mape = mean_absolute_percentage_error(y_test, lstm_predictions)
                     evaluation_results[currency]['LSTM'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
                 else:
                     print(f"LSTM test sequence creation resulted in no samples for {currency}")
                     evaluation_results[currency]['LSTM'] = 'Evaluation Failed - No Test Samples'


            else:
                 print(f"Test data for {currency} is too short for LSTM evaluation (requires at least {seq_length} data points after dropping NaNs).")
                 evaluation_results[currency]['LSTM'] = 'Evaluation Failed - Insufficient Data'

        except Exception as e:
            print(f"Error evaluating LSTM for {currency}: {e}")
            evaluation_results[currency]['LSTM'] = 'Evaluation Failed'

    # AutoTS Evaluation (Placeholder - needs implementation based on AutoTS forecasting)
    # If AutoTS was trained and forecasts were generated, evaluate here.
    # Example: if 'autots_forecasts' dictionary exists with currency as key
    # if currency in autots_forecasts:
    #     try:
    #         autots_predictions = autots_forecasts[currency] # Needs to be defined
    #         # Align AutoTS forecasts with cleaned test data
    #         # This depends on how AutoTS forecasts are generated and indexed
    #         # Assuming autots_forecasts is a Series or DataFrame with a datetime index
    #         autots_predictions_aligned = autots_predictions.reindex(test_dates).dropna().values
    #         autots_actual_filtered = actual_values[~np.isnan(autots_predictions_aligned)]
    #         autots_predictions_filtered = autots_predictions_aligned[~np.isnan(autots_predictions_aligned)]

    #         if len(autots_actual_filtered) > 0 and len(autots_predictions_filtered) == len(autots_actual_filtered):
    #             mae = mean_absolute_error(autots_actual_filtered, autots_predictions_filtered)
    #             rmse = np.sqrt(mean_squared_error(autots_actual_filtered, autots_predictions_filtered))
    #             mape = mean_absolute_percentage_error(autots_actual_filtered, autots_predictions_filtered)
    #             evaluation_results[currency]['AutoTS'] = {'MAE': mae, 'RMSE': rmse, 'MAPE': mape}
    #         else:
    #             print(f"AutoTS forecast alignment issue or no valid data for {currency}")
    #             evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'
    #     except Exception as e:
    #         print(f"Error evaluating AutoTS for {currency}: {e}")
    #         evaluation_results[currency]['AutoTS'] = 'Evaluation Failed'


# Print the evaluation results
print("\n--- Evaluation Results ---")
print(json.dumps(evaluation_results, indent=4))
# Out:
# Evaluating models for AUSTRALIA - AUSTRALIAN DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for EURO AREA - EURO/US$...
# Evaluating models for NEW ZEALAND - NEW ZELAND DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for UNITED KINGDOM - UNITED KINGDOM POUND/US$...
# Evaluating models for BRAZIL - REAL/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for CANADA - CANADIAN DOLLAR/US$...
# Evaluating models for CHINA - YUAN/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for HONG KONG - HONG KONG DOLLAR/US$...
# Evaluating models for INDIA - INDIAN RUPEE/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for KOREA - WON/US$...
# Evaluating models for MEXICO - MEXICAN PESO/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for SOUTH AFRICA - RAND/US$...
# Evaluating models for SINGAPORE - SINGAPORE DOLLAR/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for DENMARK - DANISH KRONE/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for JAPAN - YEN/US$...
# Evaluating models for MALAYSIA - RINGGIT/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for NORWAY - NORWEGIAN KRONE/US$...
# Evaluating models for SWEDEN - KRONA/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for SRI LANKA - SRI LANKAN RUPEE/US$...
# Evaluating models for SWITZERLAND - FRANC/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Evaluating models for TAIWAN - NEW TAIWAN DOLLAR/US$...
# Evaluating models for THAILAND - BAHT/US$...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# --- Evaluation Results ---
# {
#     "AUSTRALIA - AUSTRALIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.06605858939935287,
#             "RMSE": 0.0671976965067888,
#             "MAPE": 4.5168943095557506
#         },
#         "ARIMA": {
#             "MAE": 0.025867339256571645,
#             "RMSE": 0.02880088495757592,
#             "MAPE": 1.779093681180694
#         },
#         "XGBoost": {
#             "MAE": 0.013765007502692087,
#             "RMSE": 0.017274170259117046,
#             "MAPE": 0.9484185571394395
#         },
#         "LightGBM": {
#             "MAE": 0.014749361830218518,
#             "RMSE": 0.018346850239601264,
#             "MAPE": 1.0162722952351655
#         },
#         "LSTM": {
#             "MAE": 0.007915447732676674,
#             "RMSE": 0.009943261800262228,
#             "MAPE": 0.541035161890309
#         }
#     },
#     "EURO AREA - EURO/US$": {
#         "Prophet": {
#             "MAE": 0.040297489141365606,
#             "RMSE": 0.040476592005784434,
#             "MAPE": 4.46643542985669
#         },
#         "ARIMA": {
#             "MAE": 0.011331485697188342,
#             "RMSE": 0.012152627562078517,
#             "MAPE": 1.2586522851150515
#         },
#         "XGBoost": {
#             "MAE": 0.006400157873971127,
#             "RMSE": 0.007649413353545354,
#             "MAPE": 0.7117967195897394
#         },
#         "LightGBM": {
#             "MAE": 0.005197541843620305,
#             "RMSE": 0.006342994397758993,
#             "MAPE": 0.5780848020133201
#         },
#         "LSTM": {
#             "MAE": 0.010395856307900483,
#             "RMSE": 0.01092508784212956,
#             "MAPE": 1.1512408518923234
#         }
#     },
#     "NEW ZEALAND - NEW ZELAND DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.07043958653064196,
#             "RMSE": 0.07424408780241652,
#             "MAPE": 4.523775796099396
#         },
#         "ARIMA": {
#             "MAE": 0.040716293418429896,
#             "RMSE": 0.04928730762537065,
#             "MAPE": 2.6636577557099783
#         },
#         "XGBoost": {
#             "MAE": 0.03268192776271273,
#             "RMSE": 0.04219735605226402,
#             "MAPE": 2.1428468489261214
#         },
#         "LightGBM": {
#             "MAE": 0.029511913440165776,
#             "RMSE": 0.03933308408602494,
#             "MAPE": 1.9368085937075268
#         },
#         "LSTM": {
#             "MAE": 0.030104550257973036,
#             "RMSE": 0.03136156876144014,
#             "MAPE": 1.9452667330315077
#         }
#     },
#     "UNITED KINGDOM - UNITED KINGDOM POUND/US$": {
#         "Prophet": {
#             "MAE": 0.03505109063108847,
#             "RMSE": 0.036665644862374516,
#             "MAPE": 4.555211542140068
#         },
#         "ARIMA": {
#             "MAE": 0.046228990673216605,
#             "RMSE": 0.0475934611414829,
#             "MAPE": 6.0042581227275615
#         },
#         "XGBoost": {
#             "MAE": 0.0359333220720291,
#             "RMSE": 0.03734762308947538,
#             "MAPE": 4.669261845969037
#         },
#         "LightGBM": {
#             "MAE": 0.04066390712261252,
#             "RMSE": 0.04204600292439737,
#             "MAPE": 5.282773770135026
#         },
#         "LSTM": {
#             "MAE": 0.01296168530505634,
#             "RMSE": 0.013908013245183945,
#             "MAPE": 1.68699829364857
#         }
#     },
#     "BRAZIL - REAL/US$": {
#         "Prophet": {
#             "MAE": 0.31704088613709136,
#             "RMSE": 0.32568629934150556,
#             "MAPE": 7.676781005070341
#         },
#         "ARIMA": {
#             "MAE": 0.06924560579003489,
#             "RMSE": 0.08215676886370622,
#             "MAPE": 1.6743249684133705
#         },
#         "XGBoost": {
#             "MAE": 0.06726017867497033,
#             "RMSE": 0.07768518624865862,
#             "MAPE": 1.6359355528516244
#         },
#         "LightGBM": {
#             "MAE": 0.06710621184081889,
#             "RMSE": 0.07789009545629634,
#             "MAPE": 1.6304758692195542
#         },
#         "LSTM": {
#             "MAE": 0.061891719668844464,
#             "RMSE": 0.07087872977315732,
#             "MAPE": 1.5162152298571903
#         }
#     },
#     "CANADA - CANADIAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.014936071973726936,
#             "RMSE": 0.01692299846173068,
#             "MAPE": 1.1305364155894286
#         },
#         "ARIMA": {
#             "MAE": 0.014291526909026495,
#             "RMSE": 0.016308433395210705,
#             "MAPE": 1.0875099247299997
#         },
#         "XGBoost": {
#             "MAE": 0.009230845478602812,
#             "RMSE": 0.011234145966781673,
#             "MAPE": 0.7028587682367674
#         },
#         "LightGBM": {
#             "MAE": 0.009446713442268495,
#             "RMSE": 0.01149092455678973,
#             "MAPE": 0.7193201727194244
#         },
#         "LSTM": {
#             "MAE": 0.006982326648546294,
#             "RMSE": 0.008344120197138353,
#             "MAPE": 0.5307699072550854
#         }
#     },
#     "CHINA - YUAN/US$": {
#         "Prophet": {
#             "MAE": 0.14425259963150058,
#             "RMSE": 0.15055173287807835,
#             "MAPE": 2.0478990406862243
#         },
#         "ARIMA": {
#             "MAE": 0.10781173929935157,
#             "RMSE": 0.11328344102701422,
#             "MAPE": 1.5352201497179487
#         },
#         "XGBoost": {
#             "MAE": 0.08046241923740927,
#             "RMSE": 0.0870506987932787,
#             "MAPE": 1.1462624008877385
#         },
#         "LightGBM": {
#             "MAE": 0.08143027040160646,
#             "RMSE": 0.0880067663507003,
#             "MAPE": 1.1600358054757167
#         },
#         "LSTM": {
#             "MAE": 0.01750102399743125,
#             "RMSE": 0.023138762322855014,
#             "MAPE": 0.24955862069303597
#         }
#     },
#     "HONG KONG - HONG KONG DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.02993610713014705,
#             "RMSE": 0.036676184345157334,
#             "MAPE": 0.3833273488037
#         },
#         "ARIMA": {
#             "MAE": 0.02153447042477801,
#             "RMSE": 0.02872193793759003,
#             "MAPE": 0.27586347514458487
#         },
#         "XGBoost": {
#             "MAE": 0.016359676797049416,
#             "RMSE": 0.02332155034323411,
#             "MAPE": 0.209622180911828
#         },
#         "LightGBM": {
#             "MAE": 0.017926458399971503,
#             "RMSE": 0.02522962864756868,
#             "MAPE": 0.22969769781895333
#         },
#         "LSTM": {
#             "MAE": 0.007203449846350559,
#             "RMSE": 0.007768589754294819,
#             "MAPE": 0.09209006576749501
#         }
#     },
#     "INDIA - INDIAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.0389426393717167,
#             "RMSE": 1.083637839021373,
#             "MAPE": 1.4565722309466438
#         },
#         "ARIMA": {
#             "MAE": 0.3204306560852679,
#             "RMSE": 0.38060477246228225,
#             "MAPE": 0.44916101235015504
#         },
#         "XGBoost": {
#             "MAE": 0.32001251220703125,
#             "RMSE": 0.38822691436715184,
#             "MAPE": 0.44829844384767875
#         },
#         "LightGBM": {
#             "MAE": 0.3568299929224035,
#             "RMSE": 0.40686115547999163,
#             "MAPE": 0.5014372555184534
#         },
#         "LSTM": {
#             "MAE": 0.48978408150050967,
#             "RMSE": 0.5737692394531028,
#             "MAPE": 0.6859553138325281
#         }
#     },
#     "KOREA - WON/US$": {
#         "Prophet": {
#             "MAE": 46.600048055726816,
#             "RMSE": 47.63207993799701,
#             "MAPE": 3.9648124447144766
#         },
#         "ARIMA": {
#             "MAE": 20.535774674145248,
#             "RMSE": 23.44056470447449,
#             "MAPE": 1.7603629060990624
#         },
#         "XGBoost": {
#             "MAE": 20.072176164899556,
#             "RMSE": 22.983514805678553,
#             "MAPE": 1.720725174748795
#         },
#         "LightGBM": {
#             "MAE": 27.066063569095636,
#             "RMSE": 29.50549069712469,
#             "MAPE": 2.317519093026191
#         },
#         "LSTM": {
#             "MAE": 7.28791663128396,
#             "RMSE": 8.67416389475822,
#             "MAPE": 0.6239737817968138
#         }
#     },
#     "MEXICO - MEXICAN PESO/US$": {
#         "Prophet": {
#             "MAE": 0.7980272202861043,
#             "RMSE": 0.8357242957437641,
#             "MAPE": 4.168410109343636
#         },
#         "ARIMA": {
#             "MAE": 0.3922013269880228,
#             "RMSE": 0.44271169903814,
#             "MAPE": 2.0538985163187027
#         },
#         "XGBoost": {
#             "MAE": 0.33554600045340405,
#             "RMSE": 0.3905881920235257,
#             "MAPE": 1.758533737249721
#         },
#         "LightGBM": {
#             "MAE": 0.4539575695159129,
#             "RMSE": 0.49827626877029463,
#             "MAPE": 2.37551172439225
#         },
#         "LSTM": {
#             "MAE": 0.13362964596955668,
#             "RMSE": 0.16209009512155897,
#             "MAPE": 0.6925146483629576
#         }
#     },
#     "SOUTH AFRICA - RAND/US$": {
#         "Prophet": {
#             "MAE": 0.8202785260149034,
#             "RMSE": 0.8646040227303647,
#             "MAPE": 5.567808562487192
#         },
#         "ARIMA": {
#             "MAE": 0.6165626415210984,
#             "RMSE": 0.6722667113402498,
#             "MAPE": 4.245148417020389
#         },
#         "XGBoost": {
#             "MAE": 0.3088834119524275,
#             "RMSE": 0.39317964880546924,
#             "MAPE": 2.1393542600484206
#         },
#         "LightGBM": {
#             "MAE": 0.4031325289103228,
#             "RMSE": 0.4796829631355804,
#             "MAPE": 2.786171325943753
#         },
#         "LSTM": {
#             "MAE": 0.09832936112777048,
#             "RMSE": 0.13810494299785545,
#             "MAPE": 0.6697091718627961
#         }
#     },
#     "SINGAPORE - SINGAPORE DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.00864421121518742,
#             "RMSE": 0.010143412372086567,
#             "MAPE": 0.6336847792156813
#         },
#         "ARIMA": {
#             "MAE": 0.021316188610293767,
#             "RMSE": 0.02214968879811876,
#             "MAPE": 1.568260947634184
#         },
#         "XGBoost": {
#             "MAE": 0.0173948140825544,
#             "RMSE": 0.018323118520853693,
#             "MAPE": 1.2800260515377924
#         },
#         "LightGBM": {
#             "MAE": 0.02107276229395541,
#             "RMSE": 0.021914660696144502,
#             "MAPE": 1.550373018240965
#         },
#         "LSTM": {
#             "MAE": 0.005843393839960523,
#             "RMSE": 0.006447671384320302,
#             "MAPE": 0.4303543007177927
#         }
#     },
#     "DENMARK - DANISH KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.3127930711504582,
#             "RMSE": 0.3140828141622579,
#             "MAPE": 4.640136255303812
#         },
#         "ARIMA": {
#             "MAE": 0.08127893008653282,
#             "RMSE": 0.08779739758611788,
#             "MAPE": 1.2084891091881542
#         },
#         "XGBoost": {
#             "MAE": 0.04401716515677313,
#             "RMSE": 0.053696723294012295,
#             "MAPE": 0.6553585935175951
#         },
#         "LightGBM": {
#             "MAE": 0.03428406415224605,
#             "RMSE": 0.04199151106766585,
#             "MAPE": 0.5102604081584958
#         },
#         "LSTM": {
#             "MAE": 0.03764346034837806,
#             "RMSE": 0.04460744824101529,
#             "MAPE": 0.5598913390184896
#         }
#     },
#     "JAPAN - YEN/US$": {
#         "Prophet": {
#             "MAE": 1.6185573547810412,
#             "RMSE": 1.6821193714286924,
#             "MAPE": 1.48631577299787
#         },
#         "ARIMA": {
#             "MAE": 1.7768450608572819,
#             "RMSE": 1.8312754438005974,
#             "MAPE": 1.6307121431820633
#         },
#         "XGBoost": {
#             "MAE": 1.1706704602922708,
#             "RMSE": 1.2429953691005073,
#             "MAPE": 1.0739385135142911
#         },
#         "LightGBM": {
#             "MAE": 1.7730345274892865,
#             "RMSE": 1.8275543699737014,
#             "MAPE": 1.627211802392584
#         },
#         "LSTM": {
#             "MAE": 0.8497065535835597,
#             "RMSE": 0.9246096341766656,
#             "MAPE": 0.7790509637734594
#         }
#     },
#     "MALAYSIA - RINGGIT/US$": {
#         "Prophet": {
#             "MAE": 0.04177537290670784,
#             "RMSE": 0.04961961659762636,
#             "MAPE": 1.000936340979402
#         },
#         "ARIMA": {
#             "MAE": 0.030848678271793478,
#             "RMSE": 0.03851769330567343,
#             "MAPE": 0.7445747211322303
#         },
#         "XGBoost": {
#             "MAE": 0.023530012130737337,
#             "RMSE": 0.0310161991809287,
#             "MAPE": 0.5681779604659235
#         },
#         "LightGBM": {
#             "MAE": 0.027488598745999515,
#             "RMSE": 0.035421692711285854,
#             "MAPE": 0.6636960162882304
#         },
#         "LSTM": {
#             "MAE": 0.010933172126438325,
#             "RMSE": 0.01441887341276019,
#             "MAPE": 0.263807572325546
#         }
#     },
#     "NORWAY - NORWEGIAN KRONE/US$": {
#         "Prophet": {
#             "MAE": 0.6433390095412392,
#             "RMSE": 0.6580763279512826,
#             "MAPE": 7.048840870247002
#         },
#         "ARIMA": {
#             "MAE": 0.07524805252322318,
#             "RMSE": 0.12297887734928892,
#             "MAPE": 0.8387128703378078
#         },
#         "XGBoost": {
#             "MAE": 0.12273484551565993,
#             "RMSE": 0.13327437238810053,
#             "MAPE": 1.3474026467374585
#         },
#         "LightGBM": {
#             "MAE": 0.12046156309099729,
#             "RMSE": 0.1310204419353087,
#             "MAPE": 1.3227721723515555
#         },
#         "LSTM": {
#             "MAE": 0.041721704930844684,
#             "RMSE": 0.04878765397808237,
#             "MAPE": 0.4585620486594859
#         }
#     },
#     "SWEDEN - KRONA/US$": {
#         "Prophet": {
#             "MAE": 0.3339634810528948,
#             "RMSE": 0.3687304478178595,
#             "MAPE": 3.4614607795596766
#         },
#         "ARIMA": {
#             "MAE": 0.35671386750761347,
#             "RMSE": 0.383030275817486,
#             "MAPE": 3.7435651412505035
#         },
#         "XGBoost": {
#             "MAE": 0.17806895909990592,
#             "RMSE": 0.2140522867301518,
#             "MAPE": 1.8743294579729657
#         },
#         "LightGBM": {
#             "MAE": 0.16438357150193675,
#             "RMSE": 0.20180938270021723,
#             "MAPE": 1.730711591270858
#         },
#         "LSTM": {
#             "MAE": 0.0413281192281972,
#             "RMSE": 0.04980466921079855,
#             "MAPE": 0.4337535846134171
#         }
#     },
#     "SRI LANKA - SRI LANKAN RUPEE/US$": {
#         "Prophet": {
#             "MAE": 1.6458978050512125,
#             "RMSE": 1.981339299442387,
#             "MAPE": 0.9084761789035547
#         },
#         "ARIMA": {
#             "MAE": 0.8895339004509252,
#             "RMSE": 0.9946909096930927,
#             "MAPE": 0.49099750232439665
#         },
#         "XGBoost": {
#             "MAE": 0.48385931832449863,
#             "RMSE": 0.6349596633173797,
#             "MAPE": 0.2678700603060605
#         },
#         "LightGBM": {
#             "MAE": 0.8254695016133345,
#             "RMSE": 0.927207485935046,
#             "MAPE": 0.4556843518204043
#         },
#         "LSTM": {
#             "MAE": 1.8653586213485038,
#             "RMSE": 1.9436074877529361,
#             "MAPE": 1.0307987224048587
#         }
#     },
#     "SWITZERLAND - FRANC/US$": {
#         "Prophet": {
#             "MAE": 0.006368680397253272,
#             "RMSE": 0.007321715990603664,
#             "MAPE": 0.6457918895715425
#         },
#         "ARIMA": {
#             "MAE": 0.006567075035750063,
#             "RMSE": 0.00868871253282371,
#             "MAPE": 0.6679429227274819
#         },
#         "XGBoost": {
#             "MAE": 0.005869119790622169,
#             "RMSE": 0.007856604467193388,
#             "MAPE": 0.5966691175034229
#         },
#         "LightGBM": {
#             "MAE": 0.0055343234770226036,
#             "RMSE": 0.007074247276622502,
#             "MAPE": 0.5603166779404074
#         },
#         "LSTM": {
#             "MAE": 0.01079639243042988,
#             "RMSE": 0.011742058040162125,
#             "MAPE": 1.0955166429513237
#         }
#     },
#     "TAIWAN - NEW TAIWAN DOLLAR/US$": {
#         "Prophet": {
#             "MAE": 0.3026421947257079,
#             "RMSE": 0.34220320452423275,
#             "MAPE": 0.9914399338560481
#         },
#         "ARIMA": {
#             "MAE": 0.38152518157412113,
#             "RMSE": 0.42726109874836665,
#             "MAPE": 1.257910684922414
#         },
#         "XGBoost": {
#             "MAE": 0.5881658063616071,
#             "RMSE": 0.6192858825239017,
#             "MAPE": 1.9370593932017566
#         },
#         "LightGBM": {
#             "MAE": 0.7253689348008996,
#             "RMSE": 0.7508236011837933,
#             "MAPE": 2.3879721304703754
#         },
#         "LSTM": {
#             "MAE": 0.14820094564686778,
#             "RMSE": 0.16271330598946074,
#             "MAPE": 0.48860427786772564
#         }
#     },
#     "THAILAND - BAHT/US$": {
#         "Prophet": {
#             "MAE": 0.5398518631960332,
#             "RMSE": 0.5539210055784246,
#             "MAPE": 1.7859244707269732
#         },
#         "ARIMA": {
#             "MAE": 0.1566905668560512,
#             "RMSE": 0.1865894826581929,
#             "MAPE": 0.5193896227673476
#         },
#         "XGBoost": {
#             "MAE": 0.32923381260463164,
#             "RMSE": 0.34563606744274206,
#             "MAPE": 1.0900963310884224
#         },
#         "LightGBM": {
#             "MAE": 0.37006638624678406,
#             "RMSE": 0.38473174808541083,
#             "MAPE": 1.2251422774094565
#         },
#         "LSTM": {
#             "MAE": 0.1518743680871053,
#             "RMSE": 0.16581293027309435,
#             "MAPE": 0.5022519072004796
#         }
#     }
# }

# %% [markdown]
# ## Compare models
#
# ### Subtask:
# Aggregate the evaluation metrics and compare the performance of all models for each currency.

# %% [markdown]
# **Reasoning**:
# Aggregate the evaluation metrics for each currency into a pandas DataFrame for easier comparison.

# %%
model_comparison = {}

for currency, results in evaluation_results.items():
    # Filter out currencies where evaluation failed for all models
    if any(isinstance(model_metrics, dict) for model_metrics in results.values()):
        # Create a DataFrame from the dictionary of metrics for the current currency
        # Filter out models that failed evaluation before creating the DataFrame
        valid_results = {model: metrics for model, metrics in results.items() if isinstance(metrics, dict)}
        if valid_results:
            comparison_df = pd.DataFrame.from_dict(valid_results, orient='index')
            model_comparison[currency] = comparison_df
        else:
            print(f"No successful model evaluations for {currency}")
    else:
        print(f"Evaluation failed for all models for {currency}")

# Display the comparison DataFrame for each currency
print("\n--- Model Comparison Results ---")
for currency, comparison_df in model_comparison.items():
    print(f"\nComparison for {currency}:")
    display(comparison_df.round(4)) # Display metrics rounded to 4 decimal places
# Out:
# --- Model Comparison Results ---
#
# Comparison for AUSTRALIA - AUSTRALIAN DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0661  0.0672  4.5169
# ARIMA     0.0259  0.0288  1.7791
# XGBoost   0.0138  0.0173  0.9484
# LightGBM  0.0147  0.0183  1.0163
# LSTM      0.0079  0.0099  0.5410
# Comparison for EURO AREA - EURO/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0403  0.0405  4.4664
# ARIMA     0.0113  0.0122  1.2587
# XGBoost   0.0064  0.0076  0.7118
# LightGBM  0.0052  0.0063  0.5781
# LSTM      0.0104  0.0109  1.1512
# Comparison for NEW ZEALAND - NEW ZELAND DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0704  0.0742  4.5238
# ARIMA     0.0407  0.0493  2.6637
# XGBoost   0.0327  0.0422  2.1428
# LightGBM  0.0295  0.0393  1.9368
# LSTM      0.0301  0.0314  1.9453
# Comparison for UNITED KINGDOM - UNITED KINGDOM POUND/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0351  0.0367  4.5552
# ARIMA     0.0462  0.0476  6.0043
# XGBoost   0.0359  0.0373  4.6693
# LightGBM  0.0407  0.0420  5.2828
# LSTM      0.0130  0.0139  1.6870
# Comparison for BRAZIL - REAL/US$:
#              MAE    RMSE    MAPE
# Prophet   0.3170  0.3257  7.6768
# ARIMA     0.0692  0.0822  1.6743
# XGBoost   0.0673  0.0777  1.6359
# LightGBM  0.0671  0.0779  1.6305
# LSTM      0.0619  0.0709  1.5162
# Comparison for CANADA - CANADIAN DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0149  0.0169  1.1305
# ARIMA     0.0143  0.0163  1.0875
# XGBoost   0.0092  0.0112  0.7029
# LightGBM  0.0094  0.0115  0.7193
# LSTM      0.0070  0.0083  0.5308
# Comparison for CHINA - YUAN/US$:
#              MAE    RMSE    MAPE
# Prophet   0.1443  0.1506  2.0479
# ARIMA     0.1078  0.1133  1.5352
# XGBoost   0.0805  0.0871  1.1463
# LightGBM  0.0814  0.0880  1.1600
# LSTM      0.0175  0.0231  0.2496
# Comparison for HONG KONG - HONG KONG DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0299  0.0367  0.3833
# ARIMA     0.0215  0.0287  0.2759
# XGBoost   0.0164  0.0233  0.2096
# LightGBM  0.0179  0.0252  0.2297
# LSTM      0.0072  0.0078  0.0921
# Comparison for INDIA - INDIAN RUPEE/US$:
#              MAE    RMSE    MAPE
# Prophet   1.0389  1.0836  1.4566
# ARIMA     0.3204  0.3806  0.4492
# XGBoost   0.3200  0.3882  0.4483
# LightGBM  0.3568  0.4069  0.5014
# LSTM      0.4898  0.5738  0.6860
# Comparison for KOREA - WON/US$:
#               MAE     RMSE    MAPE
# Prophet   46.6000  47.6321  3.9648
# ARIMA     20.5358  23.4406  1.7604
# XGBoost   20.0722  22.9835  1.7207
# LightGBM  27.0661  29.5055  2.3175
# LSTM       7.2879   8.6742  0.6240
# Comparison for MEXICO - MEXICAN PESO/US$:
#              MAE    RMSE    MAPE
# Prophet   0.7980  0.8357  4.1684
# ARIMA     0.3922  0.4427  2.0539
# XGBoost   0.3355  0.3906  1.7585
# LightGBM  0.4540  0.4983  2.3755
# LSTM      0.1336  0.1621  0.6925
# Comparison for SOUTH AFRICA - RAND/US$:
#              MAE    RMSE    MAPE
# Prophet   0.8203  0.8646  5.5678
# ARIMA     0.6166  0.6723  4.2451
# XGBoost   0.3089  0.3932  2.1394
# LightGBM  0.4031  0.4797  2.7862
# LSTM      0.0983  0.1381  0.6697
# Comparison for SINGAPORE - SINGAPORE DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0086  0.0101  0.6337
# ARIMA     0.0213  0.0221  1.5683
# XGBoost   0.0174  0.0183  1.2800
# LightGBM  0.0211  0.0219  1.5504
# LSTM      0.0058  0.0064  0.4304
# Comparison for DENMARK - DANISH KRONE/US$:
#              MAE    RMSE    MAPE
# Prophet   0.3128  0.3141  4.6401
# ARIMA     0.0813  0.0878  1.2085
# XGBoost   0.0440  0.0537  0.6554
# LightGBM  0.0343  0.0420  0.5103
# LSTM      0.0376  0.0446  0.5599
# Comparison for JAPAN - YEN/US$:
#              MAE    RMSE    MAPE
# Prophet   1.6186  1.6821  1.4863
# ARIMA     1.7768  1.8313  1.6307
# XGBoost   1.1707  1.2430  1.0739
# LightGBM  1.7730  1.8276  1.6272
# LSTM      0.8497  0.9246  0.7791
# Comparison for MALAYSIA - RINGGIT/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0418  0.0496  1.0009
# ARIMA     0.0308  0.0385  0.7446
# XGBoost   0.0235  0.0310  0.5682
# LightGBM  0.0275  0.0354  0.6637
# LSTM      0.0109  0.0144  0.2638
# Comparison for NORWAY - NORWEGIAN KRONE/US$:
#              MAE    RMSE    MAPE
# Prophet   0.6433  0.6581  7.0488
# ARIMA     0.0752  0.1230  0.8387
# XGBoost   0.1227  0.1333  1.3474
# LightGBM  0.1205  0.1310  1.3228
# LSTM      0.0417  0.0488  0.4586
# Comparison for SWEDEN - KRONA/US$:
#              MAE    RMSE    MAPE
# Prophet   0.3340  0.3687  3.4615
# ARIMA     0.3567  0.3830  3.7436
# XGBoost   0.1781  0.2141  1.8743
# LightGBM  0.1644  0.2018  1.7307
# LSTM      0.0413  0.0498  0.4338
# Comparison for SRI LANKA - SRI LANKAN RUPEE/US$:
#              MAE    RMSE    MAPE
# Prophet   1.6459  1.9813  0.9085
# ARIMA     0.8895  0.9947  0.4910
# XGBoost   0.4839  0.6350  0.2679
# LightGBM  0.8255  0.9272  0.4557
# LSTM      1.8654  1.9436  1.0308
# Comparison for SWITZERLAND - FRANC/US$:
#              MAE    RMSE    MAPE
# Prophet   0.0064  0.0073  0.6458
# ARIMA     0.0066  0.0087  0.6679
# XGBoost   0.0059  0.0079  0.5967
# LightGBM  0.0055  0.0071  0.5603
# LSTM      0.0108  0.0117  1.0955
# Comparison for TAIWAN - NEW TAIWAN DOLLAR/US$:
#              MAE    RMSE    MAPE
# Prophet   0.3026  0.3422  0.9914
# ARIMA     0.3815  0.4273  1.2579
# XGBoost   0.5882  0.6193  1.9371
# LightGBM  0.7254  0.7508  2.3880
# LSTM      0.1482  0.1627  0.4886
# Comparison for THAILAND - BAHT/US$:
#              MAE    RMSE    MAPE
# Prophet   0.5399  0.5539  1.7859
# ARIMA     0.1567  0.1866  0.5194
# XGBoost   0.3292  0.3456  1.0901
# LightGBM  0.3701  0.3847  1.2251
# LSTM      0.1519  0.1658  0.5023

# %% [markdown]
# **Reasoning**:
# Identify the best performing model for each currency based on the evaluation metrics and report the best model for each.

# %%
best_models = {}

print("\n--- Best Performing Model per Currency ---")
for currency, comparison_df in model_comparison.items():
    # Find the row (model) with the minimum MAE
    if not comparison_df.empty:
        best_model_mae = comparison_df['MAE'].idxmin()
        best_mae_value = comparison_df['MAE'].min()

        # You could also find the best based on RMSE or MAPE if preferred
        # For this task, let's focus on MAE as the primary metric for "best"

        best_models[currency] = {'Best_Model_MAE': best_model_mae, 'MAE': best_mae_value}

        print(f"For {currency}:")
        print(f"  Best Model (based on MAE): {best_model_mae} (MAE: {best_mae_value:.4f})")
    else:
        print(f"No evaluation results available for {currency} to determine the best model.")

# Optionally, display the best models dictionary
# print("\nDictionary of Best Models:")
# print(best_models)
# Out:
# --- Best Performing Model per Currency ---
# For AUSTRALIA - AUSTRALIAN DOLLAR/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0079)
# For EURO AREA - EURO/US$:
#   Best Model (based on MAE): LightGBM (MAE: 0.0052)
# For NEW ZEALAND - NEW ZELAND DOLLAR/US$:
#   Best Model (based on MAE): LightGBM (MAE: 0.0295)
# For UNITED KINGDOM - UNITED KINGDOM POUND/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0130)
# For BRAZIL - REAL/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0619)
# For CANADA - CANADIAN DOLLAR/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0070)
# For CHINA - YUAN/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0175)
# For HONG KONG - HONG KONG DOLLAR/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0072)
# For INDIA - INDIAN RUPEE/US$:
#   Best Model (based on MAE): XGBoost (MAE: 0.3200)
# For KOREA - WON/US$:
#   Best Model (based on MAE): LSTM (MAE: 7.2879)
# For MEXICO - MEXICAN PESO/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.1336)
# For SOUTH AFRICA - RAND/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0983)
# For SINGAPORE - SINGAPORE DOLLAR/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0058)
# For DENMARK - DANISH KRONE/US$:
#   Best Model (based on MAE): LightGBM (MAE: 0.0343)
# For JAPAN - YEN/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.8497)
# For MALAYSIA - RINGGIT/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0109)
# For NORWAY - NORWEGIAN KRONE/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0417)
# For SWEDEN - KRONA/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.0413)
# For SRI LANKA - SRI LANKAN RUPEE/US$:
#   Best Model (based on MAE): XGBoost (MAE: 0.4839)
# For SWITZERLAND - FRANC/US$:
#   Best Model (based on MAE): LightGBM (MAE: 0.0055)
# For TAIWAN - NEW TAIWAN DOLLAR/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.1482)
# For THAILAND - BAHT/US$:
#   Best Model (based on MAE): LSTM (MAE: 0.1519)

# %% [markdown]
# ## Select best model
#
# ### Subtask:
# Based on the comparison, identify the best performing model for each currency.

# %% [markdown]
# **Reasoning**:
# The `model_comparison` dictionary, which contains the performance metrics for each model and currency, is already available. I will iterate through this dictionary, identify the model with the lowest Mean Absolute Error (MAE) for each currency, and store this information in a new dictionary called `best_models`. Finally, I will print the best performing model and its MAE for each currency as requested in the instructions.

# %%
best_models = {}

print("\n--- Best Performing Model per Currency (based on MAE) ---")
for currency, comparison_df in model_comparison.items():
    if not comparison_df.empty and 'MAE' in comparison_df.columns:
        # Find the model with the lowest MAE for the current currency
        best_model_name = comparison_df['MAE'].idxmin()
        best_mae_value = comparison_df['MAE'].min()

        # Store the best model and its MAE
        best_models[currency] = {'Best_Model_MAE': best_model_name, 'MAE': best_mae_value}

        # Print the result for the current currency
        print(f"For {currency}:")
        print(f"  Best Model: {best_model_name} (MAE: {best_mae_value:.4f})")
    else:
        print(f"No valid evaluation results to determine the best model for {currency}.")

# Optionally, display the final dictionary of best models
# import json
# print("\n--- Dictionary of Best Models ---")
# print(json.dumps(best_models, indent=4))
# Out:
# --- Best Performing Model per Currency (based on MAE) ---
# For AUSTRALIA - AUSTRALIAN DOLLAR/US$:
#   Best Model: LSTM (MAE: 0.0079)
# For EURO AREA - EURO/US$:
#   Best Model: LightGBM (MAE: 0.0052)
# For NEW ZEALAND - NEW ZELAND DOLLAR/US$:
#   Best Model: LightGBM (MAE: 0.0295)
# For UNITED KINGDOM - UNITED KINGDOM POUND/US$:
#   Best Model: LSTM (MAE: 0.0130)
# For BRAZIL - REAL/US$:
#   Best Model: LSTM (MAE: 0.0619)
# For CANADA - CANADIAN DOLLAR/US$:
#   Best Model: LSTM (MAE: 0.0070)
# For CHINA - YUAN/US$:
#   Best Model: LSTM (MAE: 0.0175)
# For HONG KONG - HONG KONG DOLLAR/US$:
#   Best Model: LSTM (MAE: 0.0072)
# For INDIA - INDIAN RUPEE/US$:
#   Best Model: XGBoost (MAE: 0.3200)
# For KOREA - WON/US$:
#   Best Model: LSTM (MAE: 7.2879)
# For MEXICO - MEXICAN PESO/US$:
#   Best Model: LSTM (MAE: 0.1336)
# For SOUTH AFRICA - RAND/US$:
#   Best Model: LSTM (MAE: 0.0983)
# For SINGAPORE - SINGAPORE DOLLAR/US$:
#   Best Model: LSTM (MAE: 0.0058)
# For DENMARK - DANISH KRONE/US$:
#   Best Model: LightGBM (MAE: 0.0343)
# For JAPAN - YEN/US$:
#   Best Model: LSTM (MAE: 0.8497)
# For MALAYSIA - RINGGIT/US$:
#   Best Model: LSTM (MAE: 0.0109)
# For NORWAY - NORWEGIAN KRONE/US$:
#   Best Model: LSTM (MAE: 0.0417)
# For SWEDEN - KRONA/US$:
#   Best Model: LSTM (MAE: 0.0413)
# For SRI LANKA - SRI LANKAN RUPEE/US$:
#   Best Model: XGBoost (MAE: 0.4839)
# For SWITZERLAND - FRANC/US$:
#   Best Model: LightGBM (MAE: 0.0055)
# For TAIWAN - NEW TAIWAN DOLLAR/US$:
#   Best Model: LSTM (MAE: 0.1482)
# For THAILAND - BAHT/US$:
#   Best Model: LSTM (MAE: 0.1519)

# %% [markdown]
# ## Overall Summary:
#
# **the best-performing model**
#
# The best-performing model, based on the lowest Mean Absolute Error (MAE), for each currency is as follows:
# - **AUSTRALIA - AUSTRALIAN DOLLAR/US\$**: LSTM (MAE: 0.0079)
# - **EURO AREA - EURO/US\$**: LightGBM (MAE: 0.0052)
# - **NEW ZEALAND - NEW ZELAND DOLLAR/US\$**: LightGBM (MAE: 0.0295)
# - **UNITED KINGDOM - UNITED KINGDOM POUND/US\$**: LSTM (MAE: 0.0130)
# - **BRAZIL - REAL/US\$**: LSTM (MAE: 0.0619)
# - **CANADA - CANADIAN DOLLAR/US\$**: LSTM (MAE: 0.0070)
# - **CHINA - YUAN/US\$**: LSTM (MAE: 0.0175)
# - **HONG KONG - HONG KONG DOLLAR/US\$**: LSTM (MAE: 0.0072)
# - **INDIA - INDIAN RUPEE/US\$**: XGBoost (MAE: 0.3200)
# - **KOREA - WON/US\$**: LSTM (MAE: 7.2879)
# - **MEXICO - MEXICAN PESO/US\$**: LSTM (MAE: 0.1336)
# - **SOUTH AFRICA - RAND/US\$**: LSTM (MAE: 0.0983)
# - **SINGAPORE - SINGAPORE DOLLAR/US\$**: LSTM (MAE: 0.0058)
# - **DENMARK - DANISH KRONE/US\$**: LightGBM (MAE: 0.0343)
# - **JAPAN - YEN/US\$**: LSTM (MAE: 0.8497)
# - **MALAYSIA - RINGGIT/US\$**: LSTM (MAE: 0.0109)
# - **NORWAY - NORWEGIAN KRONE/US\$**: LSTM (MAE: 0.0417)
# - **SWEDEN - KRONA/US\$**: LSTM (MAE: 0.0413)
# - **SRI LANKA - SRI LANKAN RUPEE/US\$**: XGBoost (MAE: 0.4839)
# - **SWITZERLAND - FRANC/US\$**: LightGBM (MAE: 0.0055)
# - **TAIWAN - NEW TAIWAN DOLLAR/US\$**: LSTM (MAE: 0.1482)
# - **THAILAND - BAHT/US\$**: LSTM (MAE: 0.1519)
#
# ### Data Analysis Key Findings
# * The LSTM model demonstrated the best performance for the majority of the currencies, being the top model for 16 out of the 22 currencies analyzed.
# * LightGBM was the best-performing model for 4 currencies.
# * XGBoost was the top performer for 2 currencies.
# * Prophet and ARIMA models were generally outperformed by the other models in this analysis.
# * The performance of the models varied significantly across different currencies, highlighting that there is no one-size-fits-all model for currency forecasting.
#
# ### Insights or Next Steps
# * Given the superior performance of LSTM, further tuning of its hyperparameters, such as the number of layers, neurons, and sequence length, could potentially lead to even better forecasting accuracy.
# * Exploring the use of multivariate time-series models that incorporate other economic indicators could provide a more comprehensive and potentially more accurate forecasting approach.

# %%
import os
import joblib
# Assuming you have the best_models dictionary from the previous steps
# and prophet_models, arima_models, xgboost_models, lightgbm_models, lstm_models, lstm_scalers dictionaries

# Create the 'models' directory if it doesn't exist
models_dir = 'models'
os.makedirs(models_dir, exist_ok=True)

print("Saving best performing models...")

for currency, model_info in best_models.items():
    best_model_name = model_info['Best_Model_MAE']
    model_to_save = None
    scaler_to_save = None # For LSTM scaler

    # Determine which model to save based on the best model name
    if best_model_name == 'Prophet':
        if currency in prophet_models:
            model_to_save = prophet_models[currency]
            filename = f"{currency.replace(' ', '_').replace('/', '_')}_prophet_model.pkl"
            filepath = os.path.join(models_dir, filename)
            # Prophet models can be saved with joblib or pickle
            joblib.dump(model_to_save, filepath)
            print(f"Saved Prophet model for {currency} to {filepath}")
        else:
            print(f"Prophet model for {currency} not found, cannot save.")

    elif best_model_name == 'ARIMA':
        if currency in arima_models:
            model_to_save = arima_models[currency]
            filename = f"{currency.replace(' ', '_').replace('/', '_')}_arima_model.pkl"
            filepath = os.path.join(models_dir, filename)
            # ARIMA models can be saved with joblib or pickle
            joblib.dump(model_to_save, filepath)
            print(f"Saved ARIMA model for {currency} to {filepath}")
        else:
             print(f"ARIMA model for {currency} not found, cannot save.")

    elif best_model_name == 'XGBoost':
        if currency in xgboost_models:
            model_to_save = xgboost_models[currency]
            filename = f"{currency.replace(' ', '_').replace('/', '_')}_xgboost_model.pkl"
            filepath = os.path.join(models_dir, filename)
            # XGBoost models can be saved with joblib or pickle
            joblib.dump(model_to_save, filepath)
            print(f"Saved XGBoost model for {currency} to {filepath}")
        else:
             print(f"XGBoost model for {currency} not found, cannot save.")

    elif best_model_name == 'LightGBM':
         if currency in lightgbm_models:
            model_to_save = lightgbm_models[currency]
            filename = f"{currency.replace(' ', '_').replace('/', '_')}_lightgbm_model.pkl"
            filepath = os.path.join(models_dir, filename)
            # LightGBM models can be saved with joblib or pickle
            joblib.dump(model_to_save, filepath)
            print(f"Saved LightGBM model for {currency} to {filepath}")
         else:
             print(f"LightGBM model for {currency} not found, cannot save.")

    elif best_model_name == 'LSTM':
        if currency in lstm_models and currency in lstm_scalers:
            model_to_save = lstm_models[currency]
            scaler_to_save = lstm_scalers[currency]
            filename_model = f"{currency.replace(' ', '_').replace('/', '_')}_lstm_model.h5" # Keras standard
            filename_scaler = f"{currency.replace(' ', '_').replace('/', '_')}_lstm_scaler.pkl"
            filepath_model = os.path.join(models_dir, filename_model)
            filepath_scaler = os.path.join(models_dir, filename_scaler)

            # Save LSTM model using Keras save_model
            try:
                model_to_save.save(filepath_model)
                print(f"Saved LSTM model for {currency} to {filepath_model}")
            except Exception as e:
                print(f"Could not save LSTM model for {currency} to {filepath_model}: {e}")

            # Save LSTM scaler using joblib or pickle
            try:
                 joblib.dump(scaler_to_save, filepath_scaler)
                 print(f"Saved LSTM scaler for {currency} to {filepath_scaler}")
            except Exception as e:
                 print(f"Could not save LSTM scaler for {currency} to {filepath_scaler}: {e}")

        else:
             print(f"LSTM model or scaler for {currency} not found, cannot save.")

    # Handle AutoTS if it was evaluated and found to be the best
    # elif best_model_name == 'AutoTS':
    #     if currency in autots_models:
    #         model_to_save = autots_models[currency]
    #         filename = f"{currency.replace(' ', '_').replace('/', '_')}_autots_model.pkl"
    #         filepath = os.path.join(models_dir, filename)
    #         # AutoTS models can typically be saved with joblib or pickle
    #         try:
    #              joblib.dump(model_to_save, filepath)
    #              print(f"Saved AutoTS model for {currency} to {filepath}")
    #         except Exception as e:
    #              print(f"Could not save AutoTS model for {currency} to {filepath}: {e}")
    #     else:
    #         print(f"AutoTS model for {currency} not found, cannot save.")


print("\nModel saving process complete.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saving best performing models...
# Saved LSTM model for AUSTRALIA - AUSTRALIAN DOLLAR/US$ to models/AUSTRALIA_-_AUSTRALIAN_DOLLAR_US$_lstm_model.h5
# Saved LSTM scaler for AUSTRALIA - AUSTRALIAN DOLLAR/US$ to models/AUSTRALIA_-_AUSTRALIAN_DOLLAR_US$_lstm_scaler.pkl
# Saved LightGBM model for EURO AREA - EURO/US$ to models/EURO_AREA_-_EURO_US$_lightgbm_model.pkl
# Saved LightGBM model for NEW ZEALAND - NEW ZELAND DOLLAR/US$ to models/NEW_ZEALAND_-_NEW_ZELAND_DOLLAR_US$_lightgbm_model.pkl
# Saved LSTM model for UNITED KINGDOM - UNITED KINGDOM POUND/US$ to models/UNITED_KINGDOM_-_UNITED_KINGDOM_POUND_US$_lstm_model.h5
# Saved LSTM scaler for UNITED KINGDOM - UNITED KINGDOM POUND/US$ to models/UNITED_KINGDOM_-_UNITED_KINGDOM_POUND_US$_lstm_scaler.pkl
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved LSTM model for BRAZIL - REAL/US$ to models/BRAZIL_-_REAL_US$_lstm_model.h5
# Saved LSTM scaler for BRAZIL - REAL/US$ to models/BRAZIL_-_REAL_US$_lstm_scaler.pkl
# Saved LSTM model for CANADA - CANADIAN DOLLAR/US$ to models/CANADA_-_CANADIAN_DOLLAR_US$_lstm_model.h5
# Saved LSTM scaler for CANADA - CANADIAN DOLLAR/US$ to models/CANADA_-_CANADIAN_DOLLAR_US$_lstm_scaler.pkl
# Saved LSTM model for CHINA - YUAN/US$ to models/CHINA_-_YUAN_US$_lstm_model.h5
# Saved LSTM scaler for CHINA - YUAN/US$ to models/CHINA_-_YUAN_US$_lstm_scaler.pkl
# Saved LSTM model for HONG KONG - HONG KONG DOLLAR/US$ to models/HONG_KONG_-_HONG_KONG_DOLLAR_US$_lstm_model.h5
# Saved LSTM scaler for HONG KONG - HONG KONG DOLLAR/US$ to models/HONG_KONG_-_HONG_KONG_DOLLAR_US$_lstm_scaler.pkl
# Saved XGBoost model for INDIA - INDIAN RUPEE/US$ to models/INDIA_-_INDIAN_RUPEE_US$_xgboost_model.pkl
# Saved LSTM model for KOREA - WON/US$ to models/KOREA_-_WON_US$_lstm_model.h5
# Saved LSTM scaler for KOREA - WON/US$ to models/KOREA_-_WON_US$_lstm_scaler.pkl
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved LSTM model for MEXICO - MEXICAN PESO/US$ to models/MEXICO_-_MEXICAN_PESO_US$_lstm_model.h5
# Saved LSTM scaler for MEXICO - MEXICAN PESO/US$ to models/MEXICO_-_MEXICAN_PESO_US$_lstm_scaler.pkl
# Saved LSTM model for SOUTH AFRICA - RAND/US$ to models/SOUTH_AFRICA_-_RAND_US$_lstm_model.h5
# Saved LSTM scaler for SOUTH AFRICA - RAND/US$ to models/SOUTH_AFRICA_-_RAND_US$_lstm_scaler.pkl
# Saved LSTM model for SINGAPORE - SINGAPORE DOLLAR/US$ to models/SINGAPORE_-_SINGAPORE_DOLLAR_US$_lstm_model.h5
# Saved LSTM scaler for SINGAPORE - SINGAPORE DOLLAR/US$ to models/SINGAPORE_-_SINGAPORE_DOLLAR_US$_lstm_scaler.pkl
# Saved LightGBM model for DENMARK - DANISH KRONE/US$ to models/DENMARK_-_DANISH_KRONE_US$_lightgbm_model.pkl
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved LSTM model for JAPAN - YEN/US$ to models/JAPAN_-_YEN_US$_lstm_model.h5
# Saved LSTM scaler for JAPAN - YEN/US$ to models/JAPAN_-_YEN_US$_lstm_scaler.pkl
# Saved LSTM model for MALAYSIA - RINGGIT/US$ to models/MALAYSIA_-_RINGGIT_US$_lstm_model.h5
# Saved LSTM scaler for MALAYSIA - RINGGIT/US$ to models/MALAYSIA_-_RINGGIT_US$_lstm_scaler.pkl
# Saved LSTM model for NORWAY - NORWEGIAN KRONE/US$ to models/NORWAY_-_NORWEGIAN_KRONE_US$_lstm_model.h5
# Saved LSTM scaler for NORWAY - NORWEGIAN KRONE/US$ to models/NORWAY_-_NORWEGIAN_KRONE_US$_lstm_scaler.pkl
# Saved LSTM model for SWEDEN - KRONA/US$ to models/SWEDEN_-_KRONA_US$_lstm_model.h5
# Saved LSTM scaler for SWEDEN - KRONA/US$ to models/SWEDEN_-_KRONA_US$_lstm_scaler.pkl
# Saved XGBoost model for SRI LANKA - SRI LANKAN RUPEE/US$ to models/SRI_LANKA_-_SRI_LANKAN_RUPEE_US$_xgboost_model.pkl
# Saved LightGBM model for SWITZERLAND - FRANC/US$ to models/SWITZERLAND_-_FRANC_US$_lightgbm_model.pkl
# Saved LSTM model for TAIWAN - NEW TAIWAN DOLLAR/US$ to models/TAIWAN_-_NEW_TAIWAN_DOLLAR_US$_lstm_model.h5
# Saved LSTM scaler for TAIWAN - NEW TAIWAN DOLLAR/US$ to models/TAIWAN_-_NEW_TAIWAN_DOLLAR_US$_lstm_scaler.pkl
# Saved LSTM model for THAILAND - BAHT/US$ to models/THAILAND_-_BAHT_US$_lstm_model.h5
# Saved LSTM scaler for THAILAND - BAHT/US$ to models/THAILAND_-_BAHT_US$_lstm_scaler.pkl
#
# Model saving process complete.
